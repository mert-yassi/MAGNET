# %%
SCOPETYPE = 'OPENADC'
PLATFORM = 'CWLITEARM'
CRYPTO_TARGET='NONE' 
SS_VER='SS_VER_1_1'

# %%
# Adapt this to your ChipWhisperer installation
# %run "../Setup_Scripts/Setup_Generic.ipynb"
# Out:
# INFO: Found ChipWhisperer😍
# scope.adc.samples                        changed from 500                       to 5000

# %%
samples = 500
scope.adc.samples = samples

# %%
# %%bash -s "$PLATFORM" "$CRYPTO_TARGET" "$SS_VER"
# cd target
# make clean PLATFORM=$1 CRYPTO_TARGET=$2 SS_VER=$3 -j
# make PLATFORM=$1 CRYPTO_TARGET=$2 SS_VER=$3 -j
# Out:
# SS_VER set to SS_VER_1_1
# SS_VER set to SS_VER_1_1
# rm -f -- SecNEG-CW308_CC2538.hex SecNEG-CW301_AVR.hex SecNEG-CW303.hex SecNEG-CW304.hex SecNEG-CW308_MEGARF.hex SecNEG-CW308_SAM4L.hex SecNEG-CW308_STM32F0.hex SecNEG-CW308_STM32F1.hex SecNEG-CW308_STM32F2.hex SecNEG-CW308_STM32F3.hex SecNEG-CW308_STM32F4.hex SecNEG-CW308_K24F.hex SecNEG-CW308_NRF52.hex SecNEG-CW308_AURIX.hex SecNEG-CW308_SAML11.hex SecNEG-CW308_EFM32TG11B.hex SecNEG-CWLITEARM.hex SecNEG-CWLITEXMEGA.hex SecNEG-CWNANO.hex SecNEG-CWHUSKY.hex SecNEG-CW308_K82F.hex SecNEG-CW308_PSOC62.hex SecNEG-CW308_IMXRT1062.hex SecNEG-CW308_FE310.hex SecNEG-CW308_EFR32MG21A.hex SecNEG-CW308_EFM32GG11.hex SecNEG-CW308_STM32L5.hex SecNEG-CW308_NEORV32.hex SecNEG-CW312_SAM4S.hex SecNEG-CW305_IBEX.hex
# .
# rm -rf .dep
# Cleaning project:
# rm -f -- SecNEG-CW308_CC2538.eep SecNEG-CW301_AVR.eep SecNEG-CW303.eep SecNEG-CW304.eep SecNEG-CW308_MEGARF.eep SecNEG-CW308_SAM4L.eep SecNEG-CW308_STM32F0.eep SecNEG-CW308_STM32F1.eep SecNEG-CW308_STM32F2.eep SecNEG-CW308_STM32F3.eep SecNEG-CW308_STM32F4.eep SecNEG-CW308_K24F.eep SecNEG-CW308_NRF52.eep SecNEG-CW308_AURIX.eep SecNEG-CW308_SAML11.eep SecNEG-CW308_EFM32TG11B.eep SecNEG-CWLITEARM.eep SecNEG-CWLITEXMEGA.eep SecNEG-CWNANO.eep SecNEG-CWHUSKY.eep SecNEG-CW308_K82F.eep SecNEG-CW308_PSOC62.eep SecNEG-CW308_IMXRT1062.eep SecNEG-CW308_FE310.eep SecNEG-CW308_EFR32MG21A.eep SecNEG-CW308_EFM32GG11.eep SecNEG-CW308_STM32L5.eep SecNEG-CW308_NEORV32.eep SecNEG-CW312_SAM4S.eep SecNEG-CW305_IBEX.eep
# rm -f -- SecNEG-CW308_CC2538.bin SecNEG-CW301_AVR.bin SecNEG-CW303.bin SecNEG-CW304.bin SecNEG-CW308_MEGARF.bin SecNEG-CW308_SAM4L.bin SecNEG-CW308_STM32F0.bin SecNEG-CW308_STM32F1.bin SecNEG-CW308_STM32F2.bin SecNEG-CW308_STM32F3.bin SecNEG-CW308_STM32F4.bin SecNEG-CW308_K24F.bin SecNEG-CW308_NRF52.bin SecNEG-CW308_AURIX.bin SecNEG-CW308_SAML11.bin SecNEG-CW308_EFM32TG11B.bin SecNEG-CWLITEARM.bin SecNEG-CWLITEXMEGA.bin SecNEG-CWNANO.bin SecNEG-CWHUSKY.bin SecNEG-CW308_K82F.bin SecNEG-CW308_PSOC62.bin SecNEG-CW308_IMXRT1062.bin SecNEG-CW308_FE310.bin SecNEG-CW308_EFR32MG21A.bin SecNEG-CW308_EFM32GG11.bin SecNEG-CW308_STM32L5.bin SecNEG-CW308_NEORV32.bin SecNEG-CW312_SAM4S.bin SecNEG-CW305_IBEX.bin
# rm -f -- SecNEG-CW308_CC2538.cof SecNEG-CW301_AVR.cof SecNEG-CW303.cof SecNEG-CW304.cof SecNEG-CW308_MEGARF.cof SecNEG-CW308_SAM4L.cof SecNEG-CW308_STM32F0.cof SecNEG-CW308_STM32F1.cof SecNEG-CW308_STM32F2.cof SecNEG-CW308_STM32F3.cof SecNEG-CW308_STM32F4.cof SecNEG-CW308_K24F.cof SecNEG-CW308_NRF52.cof SecNEG-CW308_AURIX.cof SecNEG-CW308_SAML11.cof SecNEG-CW308_EFM32TG11B.cof SecNEG-CWLITEARM.cof SecNEG-CWLITEXMEGA.cof SecNEG-CWNANO.cof SecNEG-CWHUSKY.cof SecNEG-CW308_K82F.cof SecNEG-CW308_PSOC62.cof SecNEG-CW308_IMXRT1062.cof SecNEG-CW308_FE310.cof SecNEG-CW308_EFR32MG21A.cof SecNEG-CW308_EFM32GG11.cof SecNEG-CW308_STM32L5.cof SecNEG-CW308_NEORV32.cof SecNEG-CW312_SAM4S.cof SecNEG-CW305_IBEX.cof
# rm -f -- SecNEG-CW308_CC2538.elf SecNEG-CW301_AVR.elf SecNEG-CW303.elf SecNEG-CW304.elf SecNEG-CW308_MEGARF.elf SecNEG-CW308_SAM4L.elf SecNEG-CW308_STM32F0.elf SecNEG-CW308_STM32F1.elf SecNEG-CW308_STM32F2.elf SecNEG-CW308_STM32F3.elf SecNEG-CW308_STM32F4.elf SecNEG-CW308_K24F.elf SecNEG-CW308_NRF52.elf SecNEG-CW308_AURIX.elf SecNEG-CW308_SAML11.elf SecNEG-CW308_EFM32TG11B.elf SecNEG-CWLITEARM.elf SecNEG-CWLITEXMEGA.elf SecNEG-CWNANO.elf SecNEG-CWHUSKY.elf SecNEG-CW308_K82F.elf SecNEG-CW308_PSOC62.elf SecNEG-CW308_IMXRT1062.elf SecNEG-CW308_FE310.elf SecNEG-CW308_EFR32MG21A.elf SecNEG-CW308_EFM32GG11.elf SecNEG-CW308_STM32L5.elf SecNEG-CW308_NEORV32.elf SecNEG-CW312_SAM4S.elf SecNEG-CW305_IBEX.elf
# rm -f -- SecNEG-CW308_CC2538.map SecNEG-CW301_AVR.map SecNEG-CW303.map SecNEG-CW304.map SecNEG-CW308_MEGARF.map SecNEG-CW308_SAM4L.map SecNEG-CW308_STM32F0.map SecNEG-CW308_STM32F1.map SecNEG-CW308_STM32F2.map SecNEG-CW308_STM32F3.map SecNEG-CW308_STM32F4.map SecNEG-CW308_K24F.map SecNEG-CW308_NRF52.map SecNEG-CW308_AURIX.map SecNEG-CW308_SAML11.map SecNEG-CW308_EFM32TG11B.map SecNEG-CWLITEARM.map SecNEG-CWLITEXMEGA.map SecNEG-CWNANO.map SecNEG-CWHUSKY.map SecNEG-CW308_K82F.map SecNEG-CW308_PSOC62.map SecNEG-CW308_IMXRT1062.map SecNEG-CW308_FE310.map SecNEG-CW308_EFR32MG21A.map SecNEG-CW308_EFM32GG11.map SecNEG-CW308_STM32L5.map SecNEG-CW308_NEORV32.map SecNEG-CW312_SAM4S.map SecNEG-CW305_IBEX.map
# rm -f -- SecNEG-CW308_CC2538.sym SecNEG-CW301_AVR.sym SecNEG-CW303.sym SecNEG-CW304.sym SecNEG-CW308_MEGARF.sym SecNEG-CW308_SAM4L.sym SecNEG-CW308_STM32F0.sym SecNEG-CW308_STM32F1.sym SecNEG-CW308_STM32F2.sym SecNEG-CW308_STM32F3.sym SecNEG-CW308_STM32F4.sym SecNEG-CW308_K24F.sym SecNEG-CW308_NRF52.sym SecNEG-CW308_AURIX.sym SecNEG-CW308_SAML11.sym SecNEG-CW308_EFM32TG11B.sym SecNEG-CWLITEARM.sym SecNEG-CWLITEXMEGA.sym SecNEG-CWNANO.sym SecNEG-CWHUSKY.sym SecNEG-CW308_K82F.sym SecNEG-CW308_PSOC62.sym SecNEG-CW308_IMXRT1062.sym SecNEG-CW308_FE310.sym SecNEG-CW308_EFR32MG21A.sym SecNEG-CW308_EFM32GG11.sym SecNEG-CW308_STM32L5.sym SecNEG-CW308_NEORV32.sym SecNEG-CW312_SAM4S.sym SecNEG-CW305_IBEX.sym
# rm -f -- SecNEG-CW308_CC2538.lss SecNEG-CW301_AVR.lss SecNEG-CW303.lss SecNEG-CW304.lss SecNEG-CW308_MEGARF.lss SecNEG-CW308_SAM4L.lss SecNEG-CW308_STM32F0.lss SecNEG-CW308_STM32F1.lss SecNEG-CW308_STM32F2.lss SecNEG-CW308_STM32F3.lss SecNEG-CW308_STM32F4.lss SecNEG-CW308_K24F.lss SecNEG-CW308_NRF52.lss SecNEG-CW308_AURIX.lss SecNEG-CW308_SAML11.lss SecNEG-CW308_EFM32TG11B.lss SecNEG-CWLITEARM.lss SecNEG-CWLITEXMEGA.lss SecNEG-CWNANO.lss SecNEG-CWHUSKY.lss SecNEG-CW308_K82F.lss SecNEG-CW308_PSOC62.lss SecNEG-CW308_IMXRT1062.lss SecNEG-CW308_FE310.lss SecNEG-CW308_EFR32MG21A.lss SecNEG-CW308_EFM32GG11.lss SecNEG-CW308_STM32L5.lss SecNEG-CW308_NEORV32.lss SecNEG-CW312_SAM4S.lss SecNEG-CW305_IBEX.lss
# rm -f -- objdir-CWLITEARM/*.o
# rm -f -- objdir-CWLITEARM/*.lst
# rm -rf objdir-CWLITEARM
# rm -f -- project.s simpleserial.s hal.s stm32f3_hal.s stm32f3_hal_lowlevel.s stm32f3_sysmem.s simpleserial.s
# rm -f -- project.d simpleserial.d hal.d stm32f3_hal.d stm32f3_hal_lowlevel.d stm32f3_sysmem.d simpleserial.d
# rm -f -- project.i simpleserial.i hal.i stm32f3_hal.i stm32f3_hal_lowlevel.i stm32f3_sysmem.i simpleserial.i
# .
# Welcome to another exciting ChipWhisperer target build!!
# SS_VER set to SS_VER_1_1
# SS_VER set to SS_VER_1_1
# arm-none-eabi-gcc (15:13.2.rel1-2) 13.2.1 20231009
# Copyright (C) 2023 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.
#
# mkdir -p objdir-CWLITEARM
# .
# Welcome to another exciting ChipWhisperer target build!!
# .
# .
# .
# .
# Compiling:
# Compiling:
# Compiling:
# Compiling:
# -en     project.c ...
# -en     ../../../firmware/mcu/simpleserial/simpleserial.c ...
# -en     ../../../firmware/mcu/hal/hal.c ...
# .
# -en     ../../../firmware/mcu/hal//stm32f3/stm32f3_hal.c ...
# Compiling:
# .
# -en     ../../../firmware/mcu/hal//stm32f3/stm32f3_hal_lowlevel.c ...
# .
# Compiling:
# .
# Assembling: Refresh_m4.S
# arm-none-eabi-gcc -c -mcpu=cortex-m4 -march=armv7e-m -std=gnu11 -I. -x assembler-with-cpp -mthumb -mfloat-abi=soft -fmessage-length=0 -ffunction-sections -DF_CPU=7372800 -Wa,-gstabs,-adhlns=objdir-CWLITEARM/Refresh_m4.lst -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal//stm32f3 -I../../../firmware/mcu/hal//stm32f3/CMSIS -I../../../firmware/mcu/hal//stm32f3/CMSIS/core -I../../../firmware/mcu/hal//stm32f3/CMSIS/device -I../../../firmware/mcu/hal//stm32f4/Legacy -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/crypto/ Refresh_m4.S -o objdir-CWLITEARM/Refresh_m4.o
# -en     ../../../firmware/mcu/hal//stm32f3/stm32f3_sysmem.c ...
# Assembling: SecNEG_m4.S
# arm-none-eabi-gcc -c -mcpu=cortex-m4 -march=armv7e-m -std=gnu11 -I. -x assembler-with-cpp -mthumb -mfloat-abi=soft -fmessage-length=0 -ffunction-sections -DF_CPU=7372800 -Wa,-gstabs,-adhlns=objdir-CWLITEARM/SecNEG_m4.lst -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal//stm32f3 -I../../../firmware/mcu/hal//stm32f3/CMSIS -I../../../firmware/mcu/hal//stm32f3/CMSIS/core -I../../../firmware/mcu/hal//stm32f3/CMSIS/device -I../../../firmware/mcu/hal//stm32f4/Legacy -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/crypto/ SecNEG_m4.S -o objdir-CWLITEARM/SecNEG_m4.o
# .
# Assembling: ../../../firmware/mcu/hal//stm32f3/stm32f3_startup.S
# arm-none-eabi-gcc -c -mcpu=cortex-m4 -march=armv7e-m -std=gnu11 -I. -x assembler-with-cpp -mthumb -mfloat-abi=soft -fmessage-length=0 -ffunction-sections -DF_CPU=7372800 -Wa,-gstabs,-adhlns=objdir-CWLITEARM/stm32f3_startup.lst -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal//stm32f3 -I../../../firmware/mcu/hal//stm32f3/CMSIS -I../../../firmware/mcu/hal//stm32f3/CMSIS/core -I../../../firmware/mcu/hal//stm32f3/CMSIS/device -I../../../firmware/mcu/hal//stm32f4/Legacy -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/crypto/ ../../../firmware/mcu/hal//stm32f3/stm32f3_startup.S -o objdir-CWLITEARM/stm32f3_startup.o
# -e Done!
# -e Done!
# -e Done!
# -e Done!
# -e Done!
# -e Done!
# .
# LINKING:
# -en     SecNEG-CWLITEARM.elf ...
# Memory region         Used Size  Region Size  %age Used
#              RAM:        1704 B        40 KB      4.16%
#              ROM:       10768 B       256 KB      4.11%
# -e Done!
# .
# .
# .
# Creating load file for Flash: SecNEG-CWLITEARM.hex
# Creating load file for Flash: SecNEG-CWLITEARM.bin
# .
# arm-none-eabi-objcopy -O ihex -R .eeprom -R .fuse -R .lock -R .signature SecNEG-CWLITEARM.elf SecNEG-CWLITEARM.hex
# arm-none-eabi-objcopy -O binary -R .eeprom -R .fuse -R .lock -R .signature SecNEG-CWLITEARM.elf SecNEG-CWLITEARM.bin
# Creating load file for EEPROM: SecNEG-CWLITEARM.eep
# arm-none-eabi-objcopy -j .eeprom --set-section-flags=.eeprom="alloc,load" \
# --change-section-lma .eeprom=0 --no-change-warnings -O ihex SecNEG-CWLITEARM.elf SecNEG-CWLITEARM.eep || exit 0
# Creating Extended Listing: SecNEG-CWLITEARM.lss
# arm-none-eabi-objdump -h -S -z SecNEG-CWLITEARM.elf > SecNEG-CWLITEARM.lss
# .
# Creating Symbol Table: SecNEG-CWLITEARM.sym
# arm-none-eabi-nm -n SecNEG-CWLITEARM.elf > SecNEG-CWLITEARM.sym
# Size after:
#    text	   data	    bss	    dec	    hex	filename
#   10744	     24	   1688	  12456	   30a8	SecNEG-CWLITEARM.elf
# +--------------------------------------------------------
# + Default target does full rebuild each time.
# + Specify buildtarget == allquick == to avoid full rebuild
# +--------------------------------------------------------
# +--------------------------------------------------------
# + Built for platform CW-Lite Arm \(STM32F3\) with:
# + CRYPTO_TARGET = NONE
# + CRYPTO_OPTIONS = AES128C
# +--------------------------------------------------------

# %%
cw.program_target(scope, prog, "target/SecNEG-{}.hex".format(PLATFORM))
# Out:
# Detected known STMF32: STM32F302xB(C)/303xB(C)
# Extended erase (0x44), this can take ten seconds or more
# Attempting to program 10767 bytes at 0x8000000
# STM32F Programming flash...
# STM32F Reading flash...
# Verified flash OK, 10767 bytes

# %%
from random import randint
from tqdm.notebook import trange
from secrets import randbits
import numpy as np

def get_traces(N):
    traces_1 = []
    traces_2 = []
    x = []
    FIXED = 1
    
    for i in trange(N, desc='Capturing traces'):
        scope.arm()

        if randbits(1):
            mask = randbits(32)
            x0 = FIXED ^ mask
            x1 = mask
    
            x0_0 = x0 % (2**8)
            x0_1 = (x0 % (2**16)) >> 8
            x0_2 = (x0 % (2**24)) >> 16
            x0_3 = x0 >> 24
    
            x1_0 = x1 % (2**8)
            x1_1 = (x1 % (2**16)) >> 8
            x1_2 = (x1 % (2**24)) >> 16
            x1_3 = x1 >> 24
            
            fixed_text = bytearray([x0_0, x0_1, x0_2, x0_3, x1_0, x1_1, x1_2, x1_3])
            
            randomness = bytearray([randbits(8), randbits(8), randbits(8), randbits(8)])
            fixed_text.extend(randomness)
            
            val = -((x0 ^ x1) & 0xFFFFFFFF) % 2**32

            target.simpleserial_write('p', fixed_text)
             
            ret = scope.capture()
            t = scope.adc.trig_count
            if ret:
                print("Target timed out!")
            response = target.simpleserial_read('r', 4)
            traces_1.append(scope.get_last_trace())
        else:
            mask = randbits(32)
            RAND = randbits(1)
            
            x0 = RAND ^ mask
            x1 = mask
            
            x0_0 = x0 % (2**8)
            x0_1 = (x0 % (2**16)) >> 8
            x0_2 = (x0 % (2**24)) >> 16
            x0_3 = x0 >> 24
    
            x1_0 = x1 % (2**8)
            x1_1 = (x1 % (2**16)) >> 8
            x1_2 = (x1 % (2**24)) >> 16
            x1_3 = x1 >> 24    

            rand_text = bytearray([x0_0, x0_1, x0_2, x0_3, x1_0, x1_1, x1_2, x1_3])
            
            randomness = bytearray([randbits(8), randbits(8), randbits(8), randbits(8)])
            rand_text.extend(randomness)
            
            val = -((x0 ^ x1) & 0xFFFFFFFF) % 2**32
    
            target.simpleserial_write('p', rand_text)
            ret = scope.capture()
            if ret:
                print("Target timed out!")
            response = target.simpleserial_read('r', 4)
            traces_2.append(scope.get_last_trace())
 
        if VERBOSE:
            print(val == (int(response[3])<<24) + (int(response[2])<<16) + (int(response[1])<<8) + int(response[0]))
            
    size = min(len(traces_1), len(traces_2))
    
    print("Trigger up for", t, "ADC cycles")
    return (traces_1[:size], traces_2[:size], x)

# %%
ch = 0
if ch == 0:
    VERBOSE = False
    nb_traces = 200000
    traces_1, traces_2, x = get_traces(nb_traces)
else:
    VERBOSE = True
    nb_traces = 100
    traces_1, traces_2, x = get_traces(nb_traces)
# Out:
# Capturing traces:   0%|          | 0/200000 [00:00<?, ?it/s]
# Trigger up for 464 ADC cycles

# %%
# %matplotlib ipympl
from scipy.stats import ttest_ind
import matplotlib.pyplot as plt
from scipy.stats import norm

alpha = 10**(-5) # error rate
sigma = 1 - (1 - alpha)**(1/samples)
th = norm.ppf(1 - sigma/2) # we adapt the threshold depending on number of samples
t_val = ttest_ind(traces_1, traces_2, axis=0, equal_var=False)[0]
plt.close()
plt.plot(t_val[0:], linewidth=0.75)
plt.plot([th]*scope.adc.samples, color = 'r')
plt.plot([-th]*scope.adc.samples, color='r')
y_offset = 0.5 * th  
plt.text(
    2,                  
    th + y_offset,
    f"th = {th:.2f}",
    color='black',
    fontsize=9,
    verticalalignment='bottom'
)
plt.ylim(-50, 50)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib ipympl
import matplotlib.pyplot as plt
plt.close()
for t in traces_1[:1]:
    plt.plot(t[:], linewidth=0.5)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
target.dis()
scope.dis()
# Out:
# True
