# %%
SCOPETYPE = 'OPENADC'
PLATFORM = 'CWLITEARM'
CRYPTO_TARGET='NONE' 
SS_VER='SS_VER_1_1'

# %%
# Adapt this to your ChipWhisperer installation
# %run "../Setup_Scripts/Setup_Generic.ipynb"
# Out:
# INFO: Found ChipWhisperer😍

# %%
samples = 5000
scope.adc.samples = samples

# %%
# %%bash -s "$PLATFORM" "$CRYPTO_TARGET" "$SS_VER"
# cd target
# make clean PLATFORM=$1 CRYPTO_TARGET=$2 SS_VER=$3 -j
# make PLATFORM=$1 CRYPTO_TARGET=$2 SS_VER=$3 -j
# Out:
# SS_VER set to SS_VER_1_1
# SS_VER set to SS_VER_1_1
# rm -f -- MaskedBernoulliExp-CW308_CC2538.hex MaskedBernoulliExp-CW301_AVR.hex MaskedBernoulliExp-CW303.hex MaskedBernoulliExp-CW304.hex MaskedBernoulliExp-CW308_MEGARF.hex MaskedBernoulliExp-CW308_SAM4L.hex MaskedBernoulliExp-CW308_STM32F0.hex MaskedBernoulliExp-CW308_STM32F1.hex MaskedBernoulliExp-CW308_STM32F2.hex MaskedBernoulliExp-CW308_STM32F3.hex MaskedBernoulliExp-CW308_STM32F4.hex MaskedBernoulliExp-CW308_K24F.hex MaskedBernoulliExp-CW308_NRF52.hex MaskedBernoulliExp-CW308_AURIX.hex MaskedBernoulliExp-CW308_SAML11.hex MaskedBernoulliExp-CW308_EFM32TG11B.hex MaskedBernoulliExp-CWLITEARM.hex MaskedBernoulliExp-CWLITEXMEGA.hex MaskedBernoulliExp-CWNANO.hex MaskedBernoulliExp-CWHUSKY.hex MaskedBernoulliExp-CW308_K82F.hex MaskedBernoulliExp-CW308_PSOC62.hex MaskedBernoulliExp-CW308_IMXRT1062.hex MaskedBernoulliExp-CW308_FE310.hex MaskedBernoulliExp-CW308_EFR32MG21A.hex MaskedBernoulliExp-CW308_EFM32GG11.hex MaskedBernoulliExp-CW308_STM32L5.hex MaskedBernoulliExp-CW308_NEORV32.hex MaskedBernoulliExp-CW312_SAM4S.hex MaskedBernoulliExp-CW305_IBEX.hex
# rm -rf .dep
# .
# Cleaning project:
# rm -f -- MaskedBernoulliExp-CW308_CC2538.eep MaskedBernoulliExp-CW301_AVR.eep MaskedBernoulliExp-CW303.eep MaskedBernoulliExp-CW304.eep MaskedBernoulliExp-CW308_MEGARF.eep MaskedBernoulliExp-CW308_SAM4L.eep MaskedBernoulliExp-CW308_STM32F0.eep MaskedBernoulliExp-CW308_STM32F1.eep MaskedBernoulliExp-CW308_STM32F2.eep MaskedBernoulliExp-CW308_STM32F3.eep MaskedBernoulliExp-CW308_STM32F4.eep MaskedBernoulliExp-CW308_K24F.eep MaskedBernoulliExp-CW308_NRF52.eep MaskedBernoulliExp-CW308_AURIX.eep MaskedBernoulliExp-CW308_SAML11.eep MaskedBernoulliExp-CW308_EFM32TG11B.eep MaskedBernoulliExp-CWLITEARM.eep MaskedBernoulliExp-CWLITEXMEGA.eep MaskedBernoulliExp-CWNANO.eep MaskedBernoulliExp
# rm -f -- project.d simpleserial.d hal.d stm32f3_hal.d stm32f3_hal_lowlevel.d stm32f3_sysmem.d simpleserial.d
# rm -f -- project.i simpleserial.i hal.i stm32f3_hal.i stm32f3_hal_lowlevel.i stm32f3_sysmem.i simpleserial.i
# .
# Welcome to another exciting ChipWhisperer target build!!
# SS_VER set to SS_VER_1_1
# SS_VER set to SS_VER_1_1
# arm-none-eabi-gcc (15:13.2.rel1-2) 13.2.1 20231009
# Copyright (C) 2023 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.
#
# mkdir -p objdir-CWLITEARM
# .
# Welcome to another exciting ChipWhisperer target build!!
# .
# .
# .
# Compiling:
# .
# Compiling:
# Compiling:
# -en     project.c ...
# Compiling:
# -en     ../../../firmware/mcu/simpleserial/simpleserial.c ...
# -en     ../../../firmware/mcu/hal/hal.c ...
# -en     ../../../firmware/mcu/hal//stm32f3/stm32f3_hal.c ...
# .
# .
# .
# Compiling:
# .
# Compiling:
# Assembling: Refresh_m4.S
# -en     ../../../firmware/mcu/hal//stm32f3/stm32f3_hal_lowlevel.c ...
# Assembling: SecAND_m4.S
# arm-none-eabi-gcc -c -mcpu=cortex-m4 -march=armv7e-m -std=gnu11 -I. -x assembler-with-cpp -mthumb -mfloat-abi=soft -fmessage-length=0 -ffunction-sections -DF_CPU=7372800 -Wa,-gstabs,-adhlns=objdir-CWLITEARM/Refresh_m4.lst -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal//stm32f3 -I../../../firmware/mcu/hal//stm32f3/CMSIS -I../../../firmware/mcu/hal//stm32f3/CMSIS/core -I../../../firmware/mcu/hal//stm32f3/CMSIS/device -I../../../firmware/mcu/hal//stm32f4/Legacy -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/crypto/ Refresh_m4.S -o objdir-CWLITEARM/Refresh_m4.o
# -en     ../../../firmware/mcu/hal//stm32f3/stm32f3_sysmem.c ...
# arm-none-eabi-gcc -c -mcpu=cortex-m4 -march=armv7e-m -std=gnu11 -I. -x assembler-with-cpp -mthumb -mfloat-abi=soft -fmessage-length=0 -ffunction-sections -DF_CPU=7372800 -Wa,-gstabs,-adhlns=objdir-CWLITEARM/SecAND_m4.lst -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal//stm32f3 -I../../../firmware/mcu/hal//stm32f3/CMSIS -I../../../firmware/mcu/hal//stm32f3/CMSIS/core -I../../../firmware/mcu/hal//stm32f3/CMSIS/device -I../../../firmware/mcu/hal//stm32f4/Legacy -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/crypto/ SecAND_m4.S -o objdir-CWLITEARM/SecAND_m4.o
# .
# .
# .
# .
# Assembling: SecOR_m4.S
# Assembling: MaskedBernoulli_m4.S
# arm-none-eabi-gcc -c -mcpu=cortex-m4 -march=armv7e-m -std=gnu11 -I. -x assembler-with-cpp -mthumb -mfloat-abi=soft -fmessage-length=0 -ffunction-sections -DF_CPU=7372800 -Wa,-gstabs,-adhlns=objdir-CWLITEARM/SecOR_m4.lst -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal//stm32f3 -I../../../firmware/mcu/hal//stm32f3/CMSIS -I../../../firmware/mcu/hal//stm32f3/CMSIS/core -I../../../firmware/mcu/hal//stm32f3/CMSIS/device -I../../../firmware/mcu/hal//stm32f4/Legacy -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/crypto/ SecOR_m4.S -o objdir-CWLITEARM/SecOR_m4.o
# arm-none-eabi-gcc -c -mcpu=cortex-m4 -march=armv7e-m -std=gnu11 -I. -x assembler-with-cpp -mthumb -mfloat-abi=soft -fmessage-length=0 -ffunction-sections -DF_CPU=7372800 -Wa,-gstabs,-adhlns=objdir-CWLITEARM/MaskedBernoulli_m4.lst -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal//stm32f3 -I../../../firmware/mcu/hal//stm32f3/CMSIS -I../../../firmware/mcu/hal//stm32f3/CMSIS/core -I../../../firmware/mcu/hal//stm32f3/CMSIS/device -I../../../firmware/mcu/hal//stm32f4/Legacy -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/crypto/ MaskedBernoulli_m4.S -o objdir-CWLITEARM/MaskedBernoulli_m4.o
# Assembling: MaskedBernoulliExp_m4.S
# arm-none-eabi-gcc -c -mcpu=cortex-m4 -march=armv7e-m -std=gnu11 -I. -x assembler-with-cpp -mthumb -mfloat-abi=soft -fmessage-length=0 -ffunction-sections -DF_CPU=7372800 -Wa,-gstabs,-adhlns=objdir-CWLITEARM/MaskedBernoulliExp_m4.lst -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal//stm32f3 -I../../../firmware/mcu/hal//stm32f3/CMSIS -I../../../firmware/mcu/hal//stm32f3/CMSIS/core -I../../../firmware/mcu/hal//stm32f3/CMSIS/device -I../../../firmware/mcu/hal//stm32f4/Legacy -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/crypto/ MaskedBernoulliExp_m4.S -o objdir-CWLITEARM/MaskedBernoulliExp_m4.o
# Assembling: ../../../firmware/mcu/hal//stm32f3/stm32f3_startup.S
# arm-none-eabi-gcc -c -mcpu=cortex-m4 -march=armv7e-m -std=gnu11 -I. -x assembler-with-cpp -mthumb -mfloat-abi=soft -fmessage-length=0 -ffunction-sections -DF_CPU=7372800 -Wa,-gstabs,-adhlns=objdir-CWLITEARM/stm32f3_startup.lst -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal//stm32f3 -I../../../firmware/mcu/hal//stm32f3/CMSIS -I../../../firmware/mcu/hal//stm32f3/CMSIS/core -I../../../firmware/mcu/hal//stm32f3/CMSIS/device -I../../../firmware/mcu/hal//stm32f4/Legacy -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/crypto/ ../../../firmware/mcu/hal//stm32f3/stm32f3_startup.S -o objdir-CWLITEARM/stm32f3_startup.o
# -e Done!
# -e Done!
# -e Done!
# -e Done!
# -e Done!
# -e Done!
# .
# LINKING:
# -en     MaskedBernoulliExp-CWLITEARM.elf ...
# Memory region         Used Size  Region Size  %age Used
#              RAM:        2136 B        40 KB      5.21%
#              ROM:       17184 B       256 KB      6.56%
# -e Done!
# .
# .
# .
# Creating load file for Flash: MaskedBernoulliExp-CWLITEARM.hex
# Creating load file for Flash: MaskedBernoulliExp-CWLITEARM.bin
# arm-none-eabi-objcopy -O ihex -R .eeprom -R .fuse -R .lock -R .signature MaskedBernoulliExp-CWLITEARM.elf MaskedBernoulliExp-CWLITEARM.hex
# arm-none-eabi-objcopy -O binary -R .eeprom -R .fuse -R .lock -R .signature MaskedBernoulliExp-CWLITEARM.elf MaskedBernoulliExp-CWLITEARM.bin
# .
# Creating load file for EEPROM: MaskedBernoulliExp-CWLITEARM.eep
# arm-none-eabi-objcopy -j .eeprom --set-section-flags=.eeprom="alloc,load" \
# --change-section-lma .eeprom=0 --no-change-warnings -O ihex MaskedBernoulliExp-CWLITEARM.elf MaskedBernoulliExp-CWLITEARM.eep || exit 0
# .
# Creating Extended Listing: MaskedBernoulliExp-CWLITEARM.lss
# arm-none-eabi-objdump -h -S -z MaskedBernoulliExp-CWLITEARM.elf > MaskedBernoulliExp-CWLITEARM.lss
# Creating Symbol Table: MaskedBernoulliExp-CWLITEARM.sym
# arm-none-eabi-nm -n MaskedBernoulliExp-CWLITEARM.elf > MaskedBernoulliExp-CWLITEARM.sym
# Size after:
#    text	   data	    bss	    dec	    hex	filename
#   17080	    104	   2040	  19224	   4b18	MaskedBernoulliExp-CWLITEARM.elf
# +--------------------------------------------------------
# + Default target does full rebuild each time.
# + Specify buildtarget == allquick == to avoid full rebuild
# +--------------------------------------------------------
# +--------------------------------------------------------
# + Built for platform CW-Lite Arm \(STM32F3\) with:
# + CRYPTO_TARGET = NONE
# + CRYPTO_OPTIONS = AES128C
# +--------------------------------------------------------

# %%
cw.program_target(scope, prog, "target/MaskedBernoulliExp-{}.hex".format(PLATFORM))
# Out:
# Detected known STMF32: STM32F302xB(C)/303xB(C)
# Extended erase (0x44), this can take ten seconds or more
# Attempting to program 17183 bytes at 0x8000000
# STM32F Programming flash...
# STM32F Reading flash...
# Verified flash OK, 17183 bytes

# %%
from random import randint
from tqdm.notebook import trange
from secrets import randbits
import numpy as np

def get_traces(N):
    traces_1 = []
    traces_2 = []
    x = []
    
    for i in trange(N, desc='Capturing traces'):
        scope.arm()

        mask = randbits(32)
        x0 = randbits(8) ^ mask
        x1 = mask

        x0_0 = x0 % (2**8)
        x0_1 = (x0 % (2**16)) >> 8
        x0_2 = (x0 % (2**24)) >> 16
        x0_3 = x0 >> 24

        x1_0 = x1 % (2**8)
        x1_1 = (x1 % (2**16)) >> 8
        x1_2 = (x1 % (2**24)) >> 16
        x1_3 = x1 >> 24
    
        text = bytearray([x0_0, x0_1, x0_2, x0_3, x1_0, x1_1, x1_2, x1_3])
        randomness = bytearray([randbits(8) for _ in range(8)])
        text.extend(randomness)
        
        target.simpleserial_write('p', text)
         
        ret = scope.capture()
        t = scope.adc.trig_count
        if ret:
            print("Target timed out!")
        response = target.simpleserial_read('r', 1)
        res = int(response[0])
        if res == 0:
            traces_1.append(scope.get_last_trace())
        if res == 1:
            traces_2.append(scope.get_last_trace())

    print("#0s: ", len(traces_1))
    print("#1s: ", len(traces_2))
    size = min(len(traces_1), len(traces_2))
    
    print("Trigger up for", t, "ADC cycles")
    return (traces_1[:size], traces_2[:size], x)

# %%
ch = 0
if ch == 0:
    VERBOSE = False
    nb_traces = 200000
    traces_1, traces_2, x = get_traces(nb_traces)
else:
    VERBOSE = True
    nb_traces = 100
    traces_1, traces_2, x = get_traces(nb_traces)
# Out:
# Capturing traces:   0%|          | 0/200000 [00:00<?, ?it/s]
# #0s:  68884
# #1s:  131116
# Trigger up for 5020 ADC cycles

# %%
# %matplotlib ipympl
from scipy.stats import ttest_ind
import matplotlib.pyplot as plt
from scipy.stats import norm

alpha = 10**(-5) # error rate
sigma = 1 - (1 - alpha)**(1/samples)
th = norm.ppf(1 - sigma/2) # we adapt the threshold depending on number of samples
t_val = ttest_ind(traces_1, traces_2, axis=0, equal_var=False)[0]
plt.close()
plt.plot(t_val[0:], linewidth=0.75)
plt.plot([th]*scope.adc.samples, color = 'r')
plt.plot([-th]*scope.adc.samples, color='r')
y_offset = 0.5 * th  
plt.text(
    2,                  
    th + y_offset,
    f"th = {th:.2f}",
    color='black',
    fontsize=9,
    verticalalignment='bottom'
)
plt.ylim(-50, 50)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib ipympl
import matplotlib.pyplot as plt

plt.close()
for t in traces_1[:10]:
    plt.plot(t[:], linewidth=0.5)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
target.dis()
scope.dis()
# Out:
# True
