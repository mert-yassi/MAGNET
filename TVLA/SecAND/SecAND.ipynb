# %%
SCOPETYPE = 'OPENADC'
PLATFORM = 'CWLITEARM'
CRYPTO_TARGET='NONE' 
SS_VER='SS_VER_1_1'

# %%
# Adapt this to your ChipWhisperer installation
# %run "../Setup_Scripts/Setup_Generic.ipynb"
# Out:
# INFO: Found ChipWhisperer😍
# scope.adc.samples                        changed from 800                       to 5000

# %%
samples = 450
scope.adc.samples = samples

# %%
# %%bash -s "$PLATFORM" "$CRYPTO_TARGET" "$SS_VER"
# cd target
# make clean PLATFORM=$1 CRYPTO_TARGET=$2 SS_VER=$3 -j
# make PLATFORM=$1 CRYPTO_TARGET=$2 SS_VER=$3 -j
# Out:
# SS_VER set to SS_VER_1_1
# SS_VER set to SS_VER_1_1
# rm -f -- SecAND-CW308_CC2538.hex SecAND-CW301_AVR.hex SecAND-CW303.hex SecAND-CW304.hex SecAND-CW308_MEGARF.hex SecAND-CW308_SAM4L.hex SecAND-CW308_STM32F0.hex SecAND-CW308_STM32F1.hex SecAND-CW308_STM32F2.hex SecAND-CW308_STM32F3.hex SecAND-CW308_STM32F4.hex SecAND-CW308_K24F.hex SecAND-CW308_NRF52.hex SecAND-CW308_AURIX.hex SecAND-CW308_SAML11.hex SecAND-CW308_EFM32TG11B.hex SecAND-CWLITEARM.hex SecAND-CWLITEXMEGA.hex SecAND-CWNANO.hex SecAND-CWHUSKY.hex SecAND-CW308_K82F.hex SecAND-CW308_PSOC62.hex SecAND-CW308_IMXRT1062.hex SecAND-CW308_FE310.hex SecAND-CW308_EFR32MG21A.hex SecAND-CW308_EFM32GG11.hex SecAND-CW308_STM32L5.hex SecAND-CW308_NEORV32.hex SecAND-CW312_SAM4S.hex SecAND-CW305_IBEX.hex
# .
# rm -rf .dep
# Cleaning project:
# rm -f -- SecAND-CW308_CC2538.eep SecAND-CW301_AVR.eep SecAND-CW303.eep SecAND-CW304.eep SecAND-CW308_MEGARF.eep SecAND-CW308_SAM4L.eep SecAND-CW308_STM32F0.eep SecAND-CW308_STM32F1.eep SecAND-CW308_STM32F2.eep SecAND-CW308_STM32F3.eep SecAND-CW308_STM32F4.eep SecAND-CW308_K24F.eep SecAND-CW308_NRF52.eep SecAND-CW308_AURIX.eep SecAND-CW308_SAML11.eep SecAND-CW308_EFM32TG11B.eep SecAND-CWLITEARM.eep SecAND-CWLITEXMEGA.eep SecAND-CWNANO.eep SecAND-CWHUSKY.eep SecAND-CW308_K82F.eep SecAND-CW308_PSOC62.eep SecAND-CW308_IMXRT1062.eep SecAND-CW308_FE310.eep SecAND-CW308_EFR32MG21A.eep SecAND-CW308_EFM32GG11.eep SecAND-CW308_STM32L5.eep SecAND-CW308_NEORV32.eep SecAND-CW312_SAM4S.eep SecAND-CW305_IBEX.eep
# rm -f -- SecAND-CW308_CC2538.bin SecAND-CW301_AVR.bin SecAND-CW303.bin SecAND-CW304.bin SecAND-CW308_MEGARF.bin SecAND-CW308_SAM4L.bin SecAND-CW308_STM32F0.bin SecAND-CW308_STM32F1.bin SecAND-CW308_STM32F2.bin SecAND-CW308_STM32F3.bin SecAND-CW308_STM32F4.bin SecAND-CW308_K24F.bin SecAND-CW308_NRF52.bin SecAND-CW308_AURIX.bin SecAND-CW308_SAML11.bin SecAND-CW308_EFM32TG11B.bin SecAND-CWLITEARM.bin SecAND-CWLITEXMEGA.bin SecAND-CWNANO.bin SecAND-CWHUSKY.bin SecAND-CW308_K82F.bin SecAND-CW308_PSOC62.bin SecAND-CW308_IMXRT1062.bin SecAND-CW308_FE310.bin SecAND-CW308_EFR32MG21A.bin SecAND-CW308_EFM32GG11.bin SecAND-CW308_STM32L5.bin SecAND-CW308_NEORV32.bin SecAND-CW312_SAM4S.bin SecAND-CW305_IBEX.bin
# rm -f -- SecAND-CW308_CC2538.cof SecAND-CW301_AVR.cof SecAND-CW303.cof SecAND-CW304.cof SecAND-CW308_MEGARF.cof SecAND-CW308_SAM4L.cof SecAND-CW308_STM32F0.cof SecAND-CW308_STM32F1.cof SecAND-CW308_STM32F2.cof SecAND-CW308_STM32F3.cof SecAND-CW308_STM32F4.cof SecAND-CW308_K24F.cof SecAND-CW308_NRF52.cof SecAND-CW308_AURIX.cof SecAND-CW308_SAML11.cof SecAND-CW308_EFM32TG11B.cof SecAND-CWLITEARM.cof SecAND-CWLITEXMEGA.cof SecAND-CWNANO.cof SecAND-CWHUSKY.cof SecAND-CW308_K82F.cof SecAND-CW308_PSOC62.cof SecAND-CW308_IMXRT1062.cof SecAND-CW308_FE310.cof SecAND-CW308_EFR32MG21A.cof SecAND-CW308_EFM32GG11.cof SecAND-CW308_STM32L5.cof SecAND-CW308_NEORV32.cof SecAND-CW312_SAM4S.cof SecAND-CW305_IBEX.cof
# rm -f -- SecAND-CW308_CC2538.elf SecAND-CW301_AVR.elf SecAND-CW303.elf SecAND-CW304.elf SecAND-CW308_MEGARF.elf SecAND-CW308_SAM4L.elf SecAND-CW308_STM32F0.elf SecAND-CW308_STM32F1.elf SecAND-CW308_STM32F2.elf SecAND-CW308_STM32F3.elf SecAND-CW308_STM32F4.elf SecAND-CW308_K24F.elf SecAND-CW308_NRF52.elf SecAND-CW308_AURIX.elf SecAND-CW308_SAML11.elf SecAND-CW308_EFM32TG11B.elf SecAND-CWLITEARM.elf SecAND-CWLITEXMEGA.elf SecAND-CWNANO.elf SecAND-CWHUSKY.elf SecAND-CW308_K82F.elf SecAND-CW308_PSOC62.elf SecAND-CW308_IMXRT1062.elf SecAND-CW308_FE310.elf SecAND-CW308_EFR32MG21A.elf SecAND-CW308_EFM32GG11.elf SecAND-CW308_STM32L5.elf SecAND-CW308_NEORV32.elf SecAND-CW312_SAM4S.elf SecAND-CW305_IBEX.elf
# rm -f -- SecAND-CW308_CC2538.map SecAND-CW301_AVR.map SecAND-CW303.map SecAND-CW304.map SecAND-CW308_MEGARF.map SecAND-CW308_SAM4L.map SecAND-CW308_STM32F0.map SecAND-CW308_STM32F1.map SecAND-CW308_STM32F2.map SecAND-CW308_STM32F3.map SecAND-CW308_STM32F4.map SecAND-CW308_K24F.map SecAND-CW308_NRF52.map SecAND-CW308_AURIX.map SecAND-CW308_SAML11.map SecAND-CW308_EFM32TG11B.map SecAND-CWLITEARM.map SecAND-CWLITEXMEGA.map SecAND-CWNANO.map SecAND-CWHUSKY.map SecAND-CW308_K82F.map SecAND-CW308_PSOC62.map SecAND-CW308_IMXRT1062.map SecAND-CW308_FE310.map SecAND-CW308_EFR32MG21A.map SecAND-CW308_EFM32GG11.map SecAND-CW308_STM32L5.map SecAND-CW308_NEORV32.map SecAND-CW312_SAM4S.map SecAND-CW305_IBEX.map
# rm -f -- SecAND-CW308_CC2538.sym SecAND-CW301_AVR.sym SecAND-CW303.sym SecAND-CW304.sym SecAND-CW308_MEGARF.sym SecAND-CW308_SAM4L.sym SecAND-CW308_STM32F0.sym SecAND-CW308_STM32F1.sym SecAND-CW308_STM32F2.sym SecAND-CW308_STM32F3.sym SecAND-CW308_STM32F4.sym SecAND-CW308_K24F.sym SecAND-CW308_NRF52.sym SecAND-CW308_AURIX.sym SecAND-CW308_SAML11.sym SecAND-CW308_EFM32TG11B.sym SecAND-CWLITEARM.sym SecAND-CWLITEXMEGA.sym SecAND-CWNANO.sym SecAND-CWHUSKY.sym SecAND-CW308_K82F.sym SecAND-CW308_PSOC62.sym SecAND-CW308_IMXRT1062.sym SecAND-CW308_FE310.sym SecAND-CW308_EFR32MG21A.sym SecAND-CW308_EFM32GG11.sym SecAND-CW308_STM32L5.sym SecAND-CW308_NEORV32.sym SecAND-CW312_SAM4S.sym SecAND-CW305_IBEX.sym
# rm -f -- SecAND-CW308_CC2538.lss SecAND-CW301_AVR.lss SecAND-CW303.lss SecAND-CW304.lss SecAND-CW308_MEGARF.lss SecAND-CW308_SAM4L.lss SecAND-CW308_STM32F0.lss SecAND-CW308_STM32F1.lss SecAND-CW308_STM32F2.lss SecAND-CW308_STM32F3.lss SecAND-CW308_STM32F4.lss SecAND-CW308_K24F.lss SecAND-CW308_NRF52.lss SecAND-CW308_AURIX.lss SecAND-CW308_SAML11.lss SecAND-CW308_EFM32TG11B.lss SecAND-CWLITEARM.lss SecAND-CWLITEXMEGA.lss SecAND-CWNANO.lss SecAND-CWHUSKY.lss SecAND-CW308_K82F.lss SecAND-CW308_PSOC62.lss SecAND-CW308_IMXRT1062.lss SecAND-CW308_FE310.lss SecAND-CW308_EFR32MG21A.lss SecAND-CW308_EFM32GG11.lss SecAND-CW308_STM32L5.lss SecAND-CW308_NEORV32.lss SecAND-CW312_SAM4S.lss SecAND-CW305_IBEX.lss
# rm -f -- objdir-CWLITEARM/*.o
# rm -f -- objdir-CWLITEARM/*.lst
# rm -rf objdir-CWLITEARM
# rm -f -- project.s simpleserial.s hal.s stm32f3_hal.s stm32f3_hal_lowlevel.s stm32f3_sysmem.s simpleserial.s
# rm -f -- project.d simpleserial.d hal.d stm32f3_hal.d stm32f3_hal_lowlevel.d stm32f3_sysmem.d simpleserial.d
# rm -f -- project.i simpleserial.i hal.i stm32f3_hal.i stm32f3_hal_lowlevel.i stm32f3_sysmem.i simpleserial.i
# .
# Welcome to another exciting ChipWhisperer target build!!
# SS_VER set to SS_VER_1_1
# SS_VER set to SS_VER_1_1
# arm-none-eabi-gcc (15:13.2.rel1-2) 13.2.1 20231009
# Copyright (C) 2023 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.
#
# mkdir -p objdir-CWLITEARM
# .
# Welcome to another exciting ChipWhisperer target build!!
# .
# .
# .
# .
# Compiling:
# Compiling:
# Compiling:
# Compiling:
# -en     project.c ...
# .
# -en     ../../../firmware/mcu/simpleserial/simpleserial.c ...
# -en     ../../../firmware/mcu/hal/hal.c ...
# -en     ../../../firmware/mcu/hal//stm32f3/stm32f3_hal.c ...
# Compiling:
# -en     ../../../firmware/mcu/hal//stm32f3/stm32f3_hal_lowlevel.c ...
# .
# .
# .
# Compiling:
# Assembling: SecAND_m4.S
# arm-none-eabi-gcc -c -mcpu=cortex-m4 -march=armv7e-m -std=gnu11 -I. -x assembler-with-cpp -mthumb -mfloat-abi=soft -fmessage-length=0 -ffunction-sections -DF_CPU=7372800 -Wa,-gstabs,-adhlns=objdir-CWLITEARM/SecAND_m4.lst -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal//stm32f3 -I../../../firmware/mcu/hal//stm32f3/CMSIS -I../../../firmware/mcu/hal//stm32f3/CMSIS/core -I../../../firmware/mcu/hal//stm32f3/CMSIS/device -I../../../firmware/mcu/hal//stm32f4/Legacy -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/crypto/ SecAND_m4.S -o objdir-CWLITEARM/SecAND_m4.o
# Assembling: ../../../firmware/mcu/hal//stm32f3/stm32f3_startup.S
# arm-none-eabi-gcc -c -mcpu=cortex-m4 -march=armv7e-m -std=gnu11 -I. -x assembler-with-cpp -mthumb -mfloat-abi=soft -fmessage-length=0 -ffunction-sections -DF_CPU=7372800 -Wa,-gstabs,-adhlns=objdir-CWLITEARM/stm32f3_startup.lst -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal//stm32f3 -I../../../firmware/mcu/hal//stm32f3/CMSIS -I../../../firmware/mcu/hal//stm32f3/CMSIS/core -I../../../firmware/mcu/hal//stm32f3/CMSIS/device -I../../../firmware/mcu/hal//stm32f4/Legacy -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/crypto/ ../../../firmware/mcu/hal//stm32f3/stm32f3_startup.S -o objdir-CWLITEARM/stm32f3_startup.o
# -en     ../../../firmware/mcu/hal//stm32f3/stm32f3_sysmem.c ...
# -e Done!
# -e Done!
# -e Done!
# -e Done!
# -e Done!
# -e Done!
# .
# LINKING:
# -en     SecAND-CWLITEARM.elf ...
# Memory region         Used Size  Region Size  %age Used
#              RAM:        1704 B        40 KB      4.16%
#              ROM:       10868 B       256 KB      4.15%
# -e Done!
# .
# .
# .
# Creating load file for Flash: SecAND-CWLITEARM.hex
# arm-none-eabi-objcopy -O ihex -R .eeprom -R .fuse -R .lock -R .signature SecAND-CWLITEARM.elf SecAND-CWLITEARM.hex
# Creating load file for Flash: SecAND-CWLITEARM.bin
# arm-none-eabi-objcopy -O binary -R .eeprom -R .fuse -R .lock -R .signature SecAND-CWLITEARM.elf SecAND-CWLITEARM.bin
# .
# Creating load file for EEPROM: SecAND-CWLITEARM.eep
# arm-none-eabi-objcopy -j .eeprom --set-section-flags=.eeprom="alloc,load" \
# --change-section-lma .eeprom=0 --no-change-warnings -O ihex SecAND-CWLITEARM.elf SecAND-CWLITEARM.eep || exit 0
# Creating Extended Listing: SecAND-CWLITEARM.lss
# arm-none-eabi-objdump -h -S -z SecAND-CWLITEARM.elf > SecAND-CWLITEARM.lss
# .
# Creating Symbol Table: SecAND-CWLITEARM.sym
# arm-none-eabi-nm -n SecAND-CWLITEARM.elf > SecAND-CWLITEARM.sym
# Size after:
#    text	   data	    bss	    dec	    hex	filename
#   10844	     24	   1688	  12556	   310c	SecAND-CWLITEARM.elf
# +--------------------------------------------------------
# + Default target does full rebuild each time.
# + Specify buildtarget == allquick == to avoid full rebuild
# +--------------------------------------------------------
# +--------------------------------------------------------
# + Built for platform CW-Lite Arm \(STM32F3\) with:
# + CRYPTO_TARGET = NONE
# + CRYPTO_OPTIONS = AES128C
# +--------------------------------------------------------

# %%
cw.program_target(scope, prog, "target/SecAND-{}.hex".format(PLATFORM))
# Out:
# Detected known STMF32: STM32F302xB(C)/303xB(C)
# Extended erase (0x44), this can take ten seconds or more
# Attempting to program 10867 bytes at 0x8000000
# STM32F Programming flash...
# STM32F Reading flash...
# Verified flash OK, 10867 bytes

# %%
from random import randint
from tqdm.notebook import trange
from secrets import randbits
import numpy as np

def get_traces(N):
    traces_1 = []
    traces_2 = []
    x = []
    FIXED = 15
    
    for i in trange(N, desc='Capturing traces'):
        scope.arm()

        mask = randbits(32)
        x0 = FIXED ^ mask
        x1 = mask

        x0_0 = x0 % (2**8)
        x0_1 = (x0 % (2**16)) >> 8
        x0_2 = (x0 % (2**24)) >> 16
        x0_3 = x0 >> 24

        x1_0 = x1 % (2**8)
        x1_1 = (x1 % (2**16)) >> 8
        x1_2 = (x1 % (2**24)) >> 16
        x1_3 = x1 >> 24
        
        fixed_text = bytearray([x0_0, x0_1, x0_2, x0_3, x1_0, x1_1, x1_2, x1_3])

        mask = randbits(32)
        y0 = FIXED ^ mask
        y1 = mask

        y0_0 = y0 % (2**8)
        y0_1 = (y0 % (2**16)) >> 8
        y0_2 = (y0 % (2**24)) >> 16
        y0_3 = y0 >> 24

        y1_0 = y1 % (2**8)
        y1_1 = (y1 % (2**16)) >> 8
        y1_2 = (y1 % (2**24)) >> 16
        y1_3 = y1 >> 24
        
        fixed_text.extend([y0_0, y0_1, y0_2, y0_3, y1_0, y1_1, y1_2, y1_3])

        randomness = bytearray([randbits(8), randbits(8), randbits(8), randbits(8)])
        fixed_text.extend(randomness)
            
        if randbits(1):
            val = ((x0 ^ x1) & (y0 ^ y1)) % 2**32 

            target.simpleserial_write('p', fixed_text)
             
            ret = scope.capture()
            t = scope.adc.trig_count
            if ret:
                print("Target timed out!")
            response = target.simpleserial_read('r', 4)
            traces_1.append(scope.get_last_trace())
        else:
            text = bytearray([randbits(8) for _ in range(len(fixed_text))])

            rnd_x0 = (text[3] << 24) |(text[2] << 16) | (text[1] << 8) | text[0]
            rnd_x1 = (text[7] << 24) |(text[6] << 16) | (text[5] << 8) | text[4]
            rnd_y0 = (text[11] << 24) |(text[10] << 16) | (text[9] << 8) | text[8]
            rnd_y1 = (text[15] << 24) |(text[14] << 16) | (text[13] << 8) | text[12]
            
            val = ((rnd_x0 ^ rnd_x1) & (rnd_y0 ^ rnd_y1)) % 2**32 
    
            target.simpleserial_write('p', text)
            ret = scope.capture()
            if ret:
                print("Target timed out!")
            response = target.simpleserial_read('r', 4)
            traces_2.append(scope.get_last_trace())
 
        if VERBOSE:
            print(val == (int(response[3])<<24) + (int(response[2])<<16) + (int(response[1])<<8) + int(response[0]))
            
    size = min(len(traces_1), len(traces_2))
    
    print("Trigger up for", t, "ADC cycles")
    return (traces_1[:size], traces_2[:size], x)

# %%
ch = 0
if ch == 0:
    VERBOSE = False
    nb_traces = 200000
    traces_1, traces_2, x = get_traces(nb_traces)
else:
    VERBOSE = True
    nb_traces = 100
    traces_1, traces_2, x = get_traces(nb_traces)
# Out:
# Capturing traces:   0%|          | 0/200000 [00:00<?, ?it/s]
# Trigger up for 432 ADC cycles

# %%
# %matplotlib ipympl
from scipy.stats import ttest_ind
import matplotlib.pyplot as plt
from scipy.stats import norm

alpha = 10**(-5) # error rate
sigma = 1 - (1 - alpha)**(1/samples)
th = norm.ppf(1 - sigma/2) # we adapt the threshold depending on number of samples
t_val = ttest_ind(traces_1, traces_2, axis=0, equal_var=False)[0]
plt.close()
plt.plot(t_val[0:], linewidth=0.75)
plt.plot([th]*scope.adc.samples, color = 'r')
plt.plot([-th]*scope.adc.samples, color='r')
y_offset = 0.5 * th  
plt.text(
    2,                  
    th + y_offset,
    f"th = {th:.2f}",
    color='black',
    fontsize=9,
    verticalalignment='bottom'
)
plt.ylim(-50, 50)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib ipympl
import matplotlib.pyplot as plt
plt.close()
for t in traces_1[:1]:
    plt.plot(t[:], linewidth=0.5)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
target.dis()
scope.dis()
# Out:
# True
