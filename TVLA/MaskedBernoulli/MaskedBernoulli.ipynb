# %%
SCOPETYPE = 'OPENADC'
PLATFORM = 'CWLITEARM'
CRYPTO_TARGET='NONE' 
SS_VER='SS_VER_1_1'

# %%
# Adapt this to your ChipWhisperer installation
# %run "../Setup_Scripts/Setup_Generic.ipynb"
# Out:
# INFO: Found ChipWhisperer😍
# scope.adc.samples                        changed from 1350                      to 5000

# %%
samples = 1500
scope.adc.samples = samples

# %%
# %%bash -s "$PLATFORM" "$CRYPTO_TARGET" "$SS_VER"
# cd target
# make clean PLATFORM=$1 CRYPTO_TARGET=$2 SS_VER=$3 -j
# make PLATFORM=$1 CRYPTO_TARGET=$2 SS_VER=$3 -j
# Out:
# SS_VER set to SS_VER_1_1
# SS_VER set to SS_VER_1_1
# rm -f -- MaskedBernoulli-CW308_CC2538.hex MaskedBernoulli-CW301_AVR.hex MaskedBernoulli-CW303.hex MaskedBernoulli-CW304.hex MaskedBernoulli-CW308_MEGARF.hex MaskedBernoulli-CW308_SAM4L.hex MaskedBernoulli-CW308_STM32F0.hex MaskedBernoulli-CW308_STM32F1.hex MaskedBernoulli-CW308_STM32F2.hex MaskedBernoulli-CW308_STM32F3.hex MaskedBernoulli-CW308_STM32F4.hex MaskedBernoulli-CW308_K24F.hex MaskedBernoulli-CW308_NRF52.hex MaskedBernoulli-CW308_AURIX.hex MaskedBernoulli-CW308_SAML11.hex MaskedBernoulli-CW308_EFM32TG11B.hex MaskedBernoulli-CWLITEARM.hex MaskedBernoulli-CWLITEXMEGA.hex MaskedBernoulli-CWNANO.hex MaskedBernoulli-CWHUSKY.hex MaskedBernoulli-CW308_K82F.hex MaskedBernoulli-CW308_PSOC62.hex MaskedBernoulli-CW308_IMXRT1062.hex MaskedBernoulli-CW308_FE310.hex MaskedBernoulli-CW308_EFR32MG21A.hex MaskedBernoulli-CW308_EFM32GG11.hex MaskedBernoulli-CW308_STM32L5.hex MaskedBernoulli-CW308_NEORV32.hex MaskedBernoulli-CW312_SAM4S.hex MaskedBernoulli-CW305_IBEX.hex
# .
# rm -rf .dep
# Cleaning project:
# rm -f -- MaskedBernoulli-CW308_CC2538.eep MaskedBernoulli-CW301_AVR.eep MaskedBernoulli-CW303.eep MaskedBernoulli-CW304.eep MaskedBernoulli-CW308_MEGARF.eep MaskedBernoulli-CW308_SAM4L.eep MaskedBernoulli-CW308_STM32F0.eep MaskedBernoulli-CW308_STM32F1.eep MaskedBernoulli-CW308_STM32F2.eep MaskedBernoulli-CW308_STM32F3.eep MaskedBernoulli-CW308_STM32F4.eep MaskedBernoulli-CW308_K24F.eep MaskedBernoulli-CW308_NRF52.eep MaskedBernoulli-CW308_AURIX.eep MaskedBernoulli-CW308_SAML11.eep MaskedBernoulli-CW308_EFM32TG11B.eep MaskedBernoulli-CWLITEARM.eep MaskedBernoulli-CWLITEXMEGA.eep MaskedBernoulli-CWNANO.eep MaskedBernoulli-CWHUSKY.eep MaskedBernoulli-CW308_K82F.eep MaskedBernoulli-CW308_PSOC62.eep MaskedBernoulli-CW308_IMXRT1062.eep MaskedBernoulli-CW308_FE310.eep MaskedBernoulli-CW308_EFR32MG21A.eep MaskedBernoulli-CW308_EFM32GG11.eep MaskedBernoulli-CW308_STM32L5.eep MaskedBernoulli-CW308_NEORV32.eep MaskedBernoulli-CW312_SAM4S.eep MaskedBernoulli-CW305_IBEX.eep
# rm -f -- MaskedBernoulli-CW308_CC2538.bin MaskedBernoulli-CW301_AVR.bin MaskedBernoulli-CW303.bin MaskedBernoulli-CW304.bin MaskedBernoulli-CW308_MEGARF.bin MaskedBernoulli-CW308_SAM4L.bin MaskedBernoulli-CW308_STM32F0.bin MaskedBernoulli-CW308_STM32F1.bin MaskedBernoulli-CW308_STM32F2.bin MaskedBernoulli-CW308_STM32F3.bin MaskedBernoulli-CW308_STM32F4.bin MaskedBernoulli-CW308_K24F.bin MaskedBernoulli-CW308_NRF52.bin MaskedBernoulli-CW308_AURIX.bin MaskedBernoulli-CW308_SAML11.bin MaskedBernoulli-CW308_EFM32TG11B.bin MaskedBernoulli-CWLITEARM.bin MaskedBernoulli-CWLITEXMEGA.bin MaskedBernoulli-CWNANO.bin MaskedBernoulli-CWHUSKY.bin MaskedBernoulli-CW308_K82F.bin MaskedBernoulli-CW308_PSOC62.bin MaskedBernoulli-CW308_IMXRT1062.bin MaskedBernoulli-CW308_FE310.bin MaskedBernoulli-CW308_EFR32MG21A.bin MaskedBernoulli-CW308_EFM32GG11.bin MaskedBernoulli-CW308_STM32L5.bin MaskedBernoulli-CW308_NEORV32.bin MaskedBernoulli-CW312_SAM4S.bin MaskedBernoulli-CW305_IBEX.bin
# rm -f -- MaskedBernoulli-CW308_CC2538.cof MaskedBernoulli-CW301_AVR.cof MaskedBernoulli-CW303.cof MaskedBernoulli-CW304.cof MaskedBernoulli-CW308_MEGARF.cof MaskedBernoulli-CW308_SAM4L.cof MaskedBernoulli-CW308_STM32F0.cof MaskedBernoulli-CW308_STM32F1.cof MaskedBernoulli-CW308_STM32F2.cof MaskedBernoulli-CW308_STM32F3.cof MaskedBernoulli-CW308_STM32F4.cof MaskedBernoulli-CW308_K24F.cof MaskedBernoulli-CW308_NRF52.cof MaskedBernoulli-CW308_AURIX.cof MaskedBernoulli-CW308_SAML11.cof MaskedBernoulli-CW308_EFM32TG11B.cof MaskedBernoulli-CWLITEARM.cof MaskedBernoulli-CWLITEXMEGA.cof MaskedBernoulli-CWNANO.cof MaskedBernoulli-CWHUSKY.cof MaskedBernoulli-CW308_K82F.cof MaskedBernoulli-CW308_PSOC62.cof MaskedBernoulli-CW308_IMXRT1062.cof MaskedBernoulli-CW308_FE310.cof MaskedBernoulli-CW308_EFR32MG21A.cof MaskedBernoulli-CW308_EFM32GG11.cof MaskedBernoulli-CW308_STM32L5.cof MaskedBernoulli-CW308_NEORV32.cof MaskedBernoulli-CW312_SAM4S.cof MaskedBernoulli-CW305_IBEX.cof
# rm -f -- MaskedBernoulli-CW308_CC2538.elf MaskedBernoulli-CW301_AVR.elf MaskedBernoulli-CW303.elf MaskedBernoulli-CW304.elf MaskedBernoulli-CW308_MEGARF.elf MaskedBernoulli-CW308_SAM4L.elf MaskedBernoulli-CW308_STM32F0.elf MaskedBernoulli-CW308_STM32F1.elf MaskedBernoulli-CW308_STM32F2.elf MaskedBernoulli-CW308_STM32F3.elf MaskedBernoulli-CW308_STM32F4.elf MaskedBernoulli-CW308_K24F.elf MaskedBernoulli-CW308_NRF52.elf MaskedBernoulli-CW308_AURIX.elf MaskedBernoulli-CW308_SAML11.elf MaskedBernoulli-CW308_EFM32TG11B.elf MaskedBernoulli-CWLITEARM.elf MaskedBernoulli-CWLITEXMEGA.elf MaskedBernoulli-CWNANO.elf MaskedBernoulli-CWHUSKY.elf MaskedBernoulli-CW308_K82F.elf MaskedBernoulli-CW308_PSOC62.elf MaskedBernoulli-CW308_IMXRT1062.elf MaskedBernoulli-CW308_FE310.elf MaskedBernoulli-CW308_EFR32MG21A.elf MaskedBernoulli-CW308_EFM32GG11.elf MaskedBernoulli-CW308_STM32L5.elf MaskedBernoulli-CW308_NEORV32.elf MaskedBernoulli-CW312_SAM4S.elf MaskedBernoulli-CW305_IBEX.elf
# rm -f -- MaskedBernoulli-CW308_CC2538.map MaskedBernoulli-CW301_AVR.map MaskedBernoulli-CW303.map MaskedBernoulli-CW304.map MaskedBernoulli-CW308_MEGARF.map MaskedBernoulli-CW308_SAM4L.map MaskedBernoulli-CW308_STM32F0.map MaskedBernoulli-CW308_STM32F1.map MaskedBernoulli-CW308_STM32F2.map MaskedBernoulli-CW308_STM32F3.map MaskedBernoulli-CW308_STM32F4.map MaskedBernoulli-CW308_K24F.map MaskedBernoulli-CW308_NRF52.map MaskedBernoulli-CW308_AURIX.map MaskedBernoulli-CW308_SAML11.map MaskedBernoulli-CW308_EFM32TG11B.map MaskedBernoulli-CWLITEARM.map MaskedBernoulli-CWLITEXMEGA.map MaskedBernoulli-CWNANO.map MaskedBernoulli-CWHUSKY.map MaskedBernoulli-CW308_K82F.map MaskedBernoulli-CW308_PSOC62.map MaskedBernoulli-CW308_IMXRT1062.map MaskedBernoulli-CW308_FE310.map MaskedBernoulli-CW308_EFR32MG21A.map MaskedBernoulli-CW308_EFM32GG11.map MaskedBernoulli-CW308_STM32L5.map MaskedBernoulli-CW308_NEORV32.map MaskedBernoulli-CW312_SAM4S.map MaskedBernoulli-CW305_IBEX.map
# rm -f -- MaskedBernoulli-CW308_CC2538.sym MaskedBernoulli-CW301_AVR.sym MaskedBernoulli-CW303.sym MaskedBernoulli-CW304.sym MaskedBernoulli-CW308_MEGARF.sym MaskedBernoulli-CW308_SAM4L.sym MaskedBernoulli-CW308_STM32F0.sym MaskedBernoulli-CW308_STM32F1.sym MaskedBernoulli-CW308_STM32F2.sym MaskedBernoulli-CW308_STM32F3.sym MaskedBernoulli-CW308_STM32F4.sym MaskedBernoulli-CW308_K24F.sym MaskedBernoulli-CW308_NRF52.sym MaskedBernoulli-CW308_AURIX.sym MaskedBernoulli-CW308_SAML11.sym MaskedBernoulli-CW308_EFM32TG11B.sym MaskedBernoulli-CWLITEARM.sym MaskedBernoulli-CWLITEXMEGA.sym MaskedBernoulli-CWNANO.sym MaskedBernoulli-CWHUSKY.sym MaskedBernoulli-CW308_K82F.sym MaskedBernoulli-CW308_PSOC62.sym MaskedBernoulli-CW308_IMXRT1062.sym MaskedBernoulli-CW308_FE310.sym MaskedBernoulli-CW308_EFR32MG21A.sym MaskedBernoulli-CW308_EFM32GG11.sym MaskedBernoulli-CW308_STM32L5.sym MaskedBernoulli-CW308_NEORV32.sym MaskedBernoulli-CW312_SAM4S.sym MaskedBernoulli-CW305_IBEX.sym
# rm -f -- MaskedBernoulli-CW308_CC2538.lss MaskedBernoulli-CW301_AVR.lss MaskedBernoulli-CW303.lss MaskedBernoulli-CW304.lss MaskedBernoulli-CW308_MEGARF.lss MaskedBernoulli-CW308_SAM4L.lss MaskedBernoulli-CW308_STM32F0.lss MaskedBernoulli-CW308_STM32F1.lss MaskedBernoulli-CW308_STM32F2.lss MaskedBernoulli-CW308_STM32F3.lss MaskedBernoulli-CW308_STM32F4.lss MaskedBernoulli-CW308_K24F.lss MaskedBernoulli-CW308_NRF52.lss MaskedBernoulli-CW308_AURIX.lss MaskedBernoulli-CW308_SAML11.lss MaskedBernoulli-CW308_EFM32TG11B.lss MaskedBernoulli-CWLITEARM.lss MaskedBernoulli-CWLITEXMEGA.lss MaskedBernoulli-CWNANO.lss MaskedBernoulli-CWHUSKY.lss MaskedBernoulli-CW308_K82F.lss MaskedBernoulli-CW308_PSOC62.lss MaskedBernoulli-CW308_IMXRT1062.lss MaskedBernoulli-CW308_FE310.lss MaskedBernoulli-CW308_EFR32MG21A.lss MaskedBernoulli-CW308_EFM32GG11.lss MaskedBernoulli-CW308_STM32L5.lss MaskedBernoulli-CW308_NEORV32.lss MaskedBernoulli-CW312_SAM4S.lss MaskedBernoulli-CW305_IBEX.lss
# rm -f -- objdir-CWLITEARM/*.o
# rm -f -- objdir-CWLITEARM/*.lst
# rm -rf objdir-CWLITEARM
# rm -f -- project.s simpleserial.s hal.s stm32f3_hal.s stm32f3_hal_lowlevel.s stm32f3_sysmem.s simpleserial.s
# rm -f -- project.d simpleserial.d hal.d stm32f3_hal.d stm32f3_hal_lowlevel.d stm32f3_sysmem.d simpleserial.d
# rm -f -- project.i simpleserial.i hal.i stm32f3_hal.i stm32f3_hal_lowlevel.i stm32f3_sysmem.i simpleserial.i
# .
# Welcome to another exciting ChipWhisperer target build!!
# SS_VER set to SS_VER_1_1
# SS_VER set to SS_VER_1_1
# arm-none-eabi-gcc (15:13.2.rel1-2) 13.2.1 20231009
# Copyright (C) 2023 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.
#
# mkdir -p objdir-CWLITEARM
# .
# Welcome to another exciting ChipWhisperer target build!!
# .
# .
# .
# .
# Compiling:
# Compiling:
# Compiling:
# Compiling:
# -en     project.c ...
# .
# -en     ../../../firmware/mcu/simpleserial/simpleserial.c ...
# -en     ../../../firmware/mcu/hal/hal.c ...
# -en     ../../../firmware/mcu/hal//stm32f3/stm32f3_hal.c ...
# Compiling:
# -en     ../../../firmware/mcu/hal//stm32f3/stm32f3_hal_lowlevel.c ...
# .
# .
# .
# .
# Compiling:
# Assembling: SecAND_m4.S
# Assembling: MaskedBernoulli_m4.S
# arm-none-eabi-gcc -c -mcpu=cortex-m4 -march=armv7e-m -std=gnu11 -I. -x assembler-with-cpp -mthumb -mfloat-abi=soft -fmessage-length=0 -ffunction-sections -DF_CPU=7372800 -Wa,-gstabs,-adhlns=objdir-CWLITEARM/SecAND_m4.lst -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal//stm32f3 -I../../../firmware/mcu/hal//stm32f3/CMSIS -I../../../firmware/mcu/hal//stm32f3/CMSIS/core -I../../../firmware/mcu/hal//stm32f3/CMSIS/device -I../../../firmware/mcu/hal//stm32f4/Legacy -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/crypto/ SecAND_m4.S -o objdir-CWLITEARM/SecAND_m4.o
# Assembling: ../../../firmware/mcu/hal//stm32f3/stm32f3_startup.S
# arm-none-eabi-gcc -c -mcpu=cortex-m4 -march=armv7e-m -std=gnu11 -I. -x assembler-with-cpp -mthumb -mfloat-abi=soft -fmessage-length=0 -ffunction-sections -DF_CPU=7372800 -Wa,-gstabs,-adhlns=objdir-CWLITEARM/MaskedBernoulli_m4.lst -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal//stm32f3 -I../../../firmware/mcu/hal//stm32f3/CMSIS -I../../../firmware/mcu/hal//stm32f3/CMSIS/core -I../../../firmware/mcu/hal//stm32f3/CMSIS/device -I../../../firmware/mcu/hal//stm32f4/Legacy -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/crypto/ MaskedBernoulli_m4.S -o objdir-CWLITEARM/MaskedBernoulli_m4.o
# -en     ../../../firmware/mcu/hal//stm32f3/stm32f3_sysmem.c ...
# arm-none-eabi-gcc -c -mcpu=cortex-m4 -march=armv7e-m -std=gnu11 -I. -x assembler-with-cpp -mthumb -mfloat-abi=soft -fmessage-length=0 -ffunction-sections -DF_CPU=7372800 -Wa,-gstabs,-adhlns=objdir-CWLITEARM/stm32f3_startup.lst -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal//stm32f3 -I../../../firmware/mcu/hal//stm32f3/CMSIS -I../../../firmware/mcu/hal//stm32f3/CMSIS/core -I../../../firmware/mcu/hal//stm32f3/CMSIS/device -I../../../firmware/mcu/hal//stm32f4/Legacy -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/crypto/ ../../../firmware/mcu/hal//stm32f3/stm32f3_startup.S -o objdir-CWLITEARM/stm32f3_startup.o
# -e Done!
# -e Done!
# -e Done!
# -e Done!
# -e Done!
# -e Done!
# .
# LINKING:
# -en     MaskedBernoulli-CWLITEARM.elf ...
# Memory region         Used Size  Region Size  %age Used
#              RAM:        2216 B        40 KB      5.41%
#              ROM:       18940 B       256 KB      7.23%
# -e Done!
# .
# .
# Creating load file for Flash: MaskedBernoulli-CWLITEARM.hex
# arm-none-eabi-objcopy -O ihex -R .eeprom -R .fuse -R .lock -R .signature MaskedBernoulli-CWLITEARM.elf MaskedBernoulli-CWLITEARM.hex
# .
# Creating load file for Flash: MaskedBernoulli-CWLITEARM.bin
# arm-none-eabi-objcopy -O binary -R .eeprom -R .fuse -R .lock -R .signature MaskedBernoulli-CWLITEARM.elf MaskedBernoulli-CWLITEARM.bin
# Creating load file for EEPROM: MaskedBernoulli-CWLITEARM.eep
# arm-none-eabi-objcopy -j .eeprom --set-section-flags=.eeprom="alloc,load" \
# --change-section-lma .eeprom=0 --no-change-warnings -O ihex MaskedBernoulli-CWLITEARM.elf MaskedBernoulli-CWLITEARM.eep || exit 0
# .
# .
# Creating Extended Listing: MaskedBernoulli-CWLITEARM.lss
# arm-none-eabi-objdump -h -S -z MaskedBernoulli-CWLITEARM.elf > MaskedBernoulli-CWLITEARM.lss
# Creating Symbol Table: MaskedBernoulli-CWLITEARM.sym
# arm-none-eabi-nm -n MaskedBernoulli-CWLITEARM.elf > MaskedBernoulli-CWLITEARM.sym
# Size after:
#    text	   data	    bss	    dec	    hex	filename
#   18836	    104	   2120	  21060	   5244	MaskedBernoulli-CWLITEARM.elf
# +--------------------------------------------------------
# + Default target does full rebuild each time.
# + Specify buildtarget == allquick == to avoid full rebuild
# +--------------------------------------------------------
# +--------------------------------------------------------
# + Built for platform CW-Lite Arm \(STM32F3\) with:
# + CRYPTO_TARGET = NONE
# + CRYPTO_OPTIONS = AES128C
# +--------------------------------------------------------

# %%
cw.program_target(scope, prog, "target/MaskedBernoulli-{}.hex".format(PLATFORM))
# Out:
# Detected known STMF32: STM32F302xB(C)/303xB(C)
# Extended erase (0x44), this can take ten seconds or more
# Attempting to program 18939 bytes at 0x8000000
# STM32F Programming flash...
# STM32F Reading flash...
# Verified flash OK, 18939 bytes

# %%
from random import randint
from tqdm.notebook import trange
from secrets import randbits
import numpy as np

def get_traces(N):
    traces_1 = []
    traces_2 = []
    x = []
    
    for i in trange(N, desc='Capturing traces'):
        scope.arm()

        random_seed = bytearray([randbits(8) for _ in range(16)])
        
        target.simpleserial_write('p', random_seed)
         
        ret = scope.capture()
        t = scope.adc.trig_count
        if ret:
            print("Target timed out!")
        response = target.simpleserial_read('r', 1)
        res = int(response[0])
        if res == 0:
            traces_1.append(scope.get_last_trace())
        if res == 1:
            traces_2.append(scope.get_last_trace())

    print("#0s: ", len(traces_1))
    print("#1s: ", len(traces_2))
    size = min(len(traces_1), len(traces_2))
    
    print("Trigger up for", t, "ADC cycles")
    return (traces_1[:size], traces_2[:size], x)

# %%
ch = 0
if ch == 0:
    VERBOSE = False
    nb_traces = 200000
    traces_1, traces_2, x = get_traces(nb_traces)
else:
    VERBOSE = True
    nb_traces = 100
    traces_1, traces_2, x = get_traces(nb_traces)
# Out:
# Capturing traces:   0%|          | 0/200000 [00:00<?, ?it/s]
# #0s:  49835
# #1s:  150165
# Trigger up for 1460 ADC cycles

# %%
# %matplotlib ipympl
from scipy.stats import ttest_ind
import matplotlib.pyplot as plt
from scipy.stats import norm

alpha = 10**(-5) # error rate
sigma = 1 - (1 - alpha)**(1/samples)
th = norm.ppf(1 - sigma/2) # we adapt the threshold depending on number of samples
t_val = ttest_ind(traces_1, traces_2, axis=0, equal_var=False)[0]
plt.close()
plt.plot(t_val[0:], linewidth=0.75)
plt.plot([th]*scope.adc.samples, color = 'r')
plt.plot([-th]*scope.adc.samples, color='r')
y_offset = 0.5 * th  
plt.text(
    2,                  
    th + y_offset,
    f"th = {th:.2f}",
    color='black',
    fontsize=9,
    verticalalignment='bottom'
)
plt.ylim(-50, 50)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib ipympl
import matplotlib.pyplot as plt

plt.close()
for t in traces_1[:10]:
    plt.plot(t[:], linewidth=0.5)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
target.dis()
scope.dis()
# Out:
# True
