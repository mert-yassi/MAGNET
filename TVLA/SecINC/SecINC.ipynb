# %%
SCOPETYPE = 'OPENADC'
PLATFORM = 'CWLITEARM'
CRYPTO_TARGET='NONE' 
SS_VER='SS_VER_1_1'

# %%
# Adapt this to your ChipWhisperer installation
# %run "../Setup_Scripts/Setup_Generic.ipynb"
# Out:
# INFO: Found ChipWhisperer😍

# %%
samples = 1900
scope.adc.samples = samples

# %%
# %%bash -s "$PLATFORM" "$CRYPTO_TARGET" "$SS_VER"
# cd target
# make clean PLATFORM=$1 CRYPTO_TARGET=$2 SS_VER=$3 -j
# make PLATFORM=$1 CRYPTO_TARGET=$2 SS_VER=$3 -j
# Out:
# SS_VER set to SS_VER_1_1
# SS_VER set to SS_VER_1_1
# rm -f -- SecINC-CW308_CC2538.hex SecINC-CW301_AVR.hex SecINC-CW303.hex SecINC-CW304.hex SecINC-CW308_MEGARF.hex SecINC-CW308_SAM4L.hex SecINC-CW308_STM32F0.hex SecINC-CW308_STM32F1.hex SecINC-CW308_STM32F2.hex SecINC-CW308_STM32F3.hex SecINC-CW308_STM32F4.hex SecINC-CW308_K24F.hex SecINC-CW308_NRF52.hex SecINC-CW308_AURIX.hex SecINC-CW308_SAML11.hex SecINC-CW308_EFM32TG11B.hex SecINC-CWLITEARM.hex SecINC-CWLITEXMEGA.hex SecINC-CWNANO.hex SecINC-CWHUSKY.hex SecINC-CW308_K82F.hex SecINC-CW308_PSOC62.hex SecINC-CW308_IMXRT1062.hex SecINC-CW308_FE310.hex SecINC-CW308_EFR32MG21A.hex SecINC-CW308_EFM32GG11.hex SecINC-CW308_STM32L5.hex SecINC-CW308_NEORV32.hex SecINC-CW312_SAM4S.hex SecINC-CW305_IBEX.hex
# .
# rm -rf .dep
# Cleaning project:
# rm -f -- SecINC-CW308_CC2538.eep SecINC-CW301_AVR.eep SecINC-CW303.eep SecINC-CW304.eep SecINC-CW308_MEGARF.eep SecINC-CW308_SAM4L.eep SecINC-CW308_STM32F0.eep SecINC-CW308_STM32F1.eep SecINC-CW308_STM32F2.eep SecINC-CW308_STM32F3.eep SecINC-CW308_STM32F4.eep SecINC-CW308_K24F.eep SecINC-CW308_NRF52.eep SecINC-CW308_AURIX.eep SecINC-CW308_SAML11.eep SecINC-CW308_EFM32TG11B.eep SecINC-CWLITEARM.eep SecINC-CWLITEXMEGA.eep SecINC-CWNANO.eep SecINC-CWHUSKY.eep SecINC-CW308_K82F.eep SecINC-CW308_PSOC62.eep SecINC-CW308_IMXRT1062.eep SecINC-CW308_FE310.eep SecINC-CW308_EFR32MG21A.eep SecINC-CW308_EFM32GG11.eep SecINC-CW308_STM32L5.eep SecINC-CW308_NEORV32.eep SecINC-CW312_SAM4S.eep SecINC-CW305_IBEX.eep
# rm -f -- SecINC-CW308_CC2538.bin SecINC-CW301_AVR.bin SecINC-CW303.bin SecINC-CW304.bin SecINC-CW308_MEGARF.bin SecINC-CW308_SAM4L.bin SecINC-CW308_STM32F0.bin SecINC-CW308_STM32F1.bin SecINC-CW308_STM32F2.bin SecINC-CW308_STM32F3.bin SecINC-CW308_STM32F4.bin SecINC-CW308_K24F.bin SecINC-CW308_NRF52.bin SecINC-CW308_AURIX.bin SecINC-CW308_SAML11.bin SecINC-CW308_EFM32TG11B.bin SecINC-CWLITEARM.bin SecINC-CWLITEXMEGA.bin SecINC-CWNANO.bin SecINC-CWHUSKY.bin SecINC-CW308_K82F.bin SecINC-CW308_PSOC62.bin SecINC-CW308_IMXRT1062.bin SecINC-CW308_FE310.bin SecINC-CW308_EFR32MG21A.bin SecINC-CW308_EFM32GG11.bin SecINC-CW308_STM32L5.bin SecINC-CW308_NEORV32.bin SecINC-CW312_SAM4S.bin SecINC-CW305_IBEX.bin
# rm -f -- SecINC-CW308_CC2538.cof SecINC-CW301_AVR.cof SecINC-CW303.cof SecINC-CW304.cof SecINC-CW308_MEGARF.cof SecINC-CW308_SAM4L.cof SecINC-CW308_STM32F0.cof SecINC-CW308_STM32F1.cof SecINC-CW308_STM32F2.cof SecINC-CW308_STM32F3.cof SecINC-CW308_STM32F4.cof SecINC-CW308_K24F.cof SecINC-CW308_NRF52.cof SecINC-CW308_AURIX.cof SecINC-CW308_SAML11.cof SecINC-CW308_EFM32TG11B.cof SecINC-CWLITEARM.cof SecINC-CWLITEXMEGA.cof SecINC-CWNANO.cof SecINC-CWHUSKY.cof SecINC-CW308_K82F.cof SecINC-CW308_PSOC62.cof SecINC-CW308_IMXRT1062.cof SecINC-CW308_FE310.cof SecINC-CW308_EFR32MG21A.cof SecINC-CW308_EFM32GG11.cof SecINC-CW308_STM32L5.cof SecINC-CW308_NEORV32.cof SecINC-CW312_SAM4S.cof SecINC-CW305_IBEX.cof
# rm -f -- SecINC-CW308_CC2538.elf SecINC-CW301_AVR.elf SecINC-CW303.elf SecINC-CW304.elf SecINC-CW308_MEGARF.elf SecINC-CW308_SAM4L.elf SecINC-CW308_STM32F0.elf SecINC-CW308_STM32F1.elf SecINC-CW308_STM32F2.elf SecINC-CW308_STM32F3.elf SecINC-CW308_STM32F4.elf SecINC-CW308_K24F.elf SecINC-CW308_NRF52.elf SecINC-CW308_AURIX.elf SecINC-CW308_SAML11.elf SecINC-CW308_EFM32TG11B.elf SecINC-CWLITEARM.elf SecINC-CWLITEXMEGA.elf SecINC-CWNANO.elf SecINC-CWHUSKY.elf SecINC-CW308_K82F.elf SecINC-CW308_PSOC62.elf SecINC-CW308_IMXRT1062.elf SecINC-CW308_FE310.elf SecINC-CW308_EFR32MG21A.elf SecINC-CW308_EFM32GG11.elf SecINC-CW308_STM32L5.elf SecINC-CW308_NEORV32.elf SecINC-CW312_SAM4S.elf SecINC-CW305_IBEX.elf
# rm -f -- SecINC-CW308_CC2538.map SecINC-CW301_AVR.map SecINC-CW303.map SecINC-CW304.map SecINC-CW308_MEGARF.map SecINC-CW308_SAM4L.map SecINC-CW308_STM32F0.map SecINC-CW308_STM32F1.map SecINC-CW308_STM32F2.map SecINC-CW308_STM32F3.map SecINC-CW308_STM32F4.map SecINC-CW308_K24F.map SecINC-CW308_NRF52.map SecINC-CW308_AURIX.map SecINC-CW308_SAML11.map SecINC-CW308_EFM32TG11B.map SecINC-CWLITEARM.map SecINC-CWLITEXMEGA.map SecINC-CWNANO.map SecINC-CWHUSKY.map SecINC-CW308_K82F.map SecINC-CW308_PSOC62.map SecINC-CW308_IMXRT1062.map SecINC-CW308_FE310.map SecINC-CW308_EFR32MG21A.map SecINC-CW308_EFM32GG11.map SecINC-CW308_STM32L5.map SecINC-CW308_NEORV32.map SecINC-CW312_SAM4S.map SecINC-CW305_IBEX.map
# rm -f -- SecINC-CW308_CC2538.sym SecINC-CW301_AVR.sym SecINC-CW303.sym SecINC-CW304.sym SecINC-CW308_MEGARF.sym SecINC-CW308_SAM4L.sym SecINC-CW308_STM32F0.sym SecINC-CW308_STM32F1.sym SecINC-CW308_STM32F2.sym SecINC-CW308_STM32F3.sym SecINC-CW308_STM32F4.sym SecINC-CW308_K24F.sym SecINC-CW308_NRF52.sym SecINC-CW308_AURIX.sym SecINC-CW308_SAML11.sym SecINC-CW308_EFM32TG11B.sym SecINC-CWLITEARM.sym SecINC-CWLITEXMEGA.sym SecINC-CWNANO.sym SecINC-CWHUSKY.sym SecINC-CW308_K82F.sym SecINC-CW308_PSOC62.sym SecINC-CW308_IMXRT1062.sym SecINC-CW308_FE310.sym SecINC-CW308_EFR32MG21A.sym SecINC-CW308_EFM32GG11.sym SecINC-CW308_STM32L5.sym SecINC-CW308_NEORV32.sym SecINC-CW312_SAM4S.sym SecINC-CW305_IBEX.sym
# rm -f -- SecINC-CW308_CC2538.lss SecINC-CW301_AVR.lss SecINC-CW303.lss SecINC-CW304.lss SecINC-CW308_MEGARF.lss SecINC-CW308_SAM4L.lss SecINC-CW308_STM32F0.lss SecINC-CW308_STM32F1.lss SecINC-CW308_STM32F2.lss SecINC-CW308_STM32F3.lss SecINC-CW308_STM32F4.lss SecINC-CW308_K24F.lss SecINC-CW308_NRF52.lss SecINC-CW308_AURIX.lss SecINC-CW308_SAML11.lss SecINC-CW308_EFM32TG11B.lss SecINC-CWLITEARM.lss SecINC-CWLITEXMEGA.lss SecINC-CWNANO.lss SecINC-CWHUSKY.lss SecINC-CW308_K82F.lss SecINC-CW308_PSOC62.lss SecINC-CW308_IMXRT1062.lss SecINC-CW308_FE310.lss SecINC-CW308_EFR32MG21A.lss SecINC-CW308_EFM32GG11.lss SecINC-CW308_STM32L5.lss SecINC-CW308_NEORV32.lss SecINC-CW312_SAM4S.lss SecINC-CW305_IBEX.lss
# rm -f -- objdir-CWLITEARM/*.o
# rm -f -- objdir-CWLITEARM/*.lst
# rm -rf objdir-CWLITEARM
# rm -f -- project.s simpleserial.s hal.s stm32f3_hal.s stm32f3_hal_lowlevel.s stm32f3_sysmem.s simpleserial.s
# rm -f -- project.d simpleserial.d hal.d stm32f3_hal.d stm32f3_hal_lowlevel.d stm32f3_sysmem.d simpleserial.d
# rm -f -- project.i simpleserial.i hal.i stm32f3_hal.i stm32f3_hal_lowlevel.i stm32f3_sysmem.i simpleserial.i
# .
# Welcome to another exciting ChipWhisperer target build!!
# SS_VER set to SS_VER_1_1
# SS_VER set to SS_VER_1_1
# arm-none-eabi-gcc (15:13.2.rel1-2) 13.2.1 20231009
# Copyright (C) 2023 Free Software Foundation, Inc.
# This is free software; see the source for copying conditions.  There is NO
# warranty; not even for MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE.
#
# mkdir -p objdir-CWLITEARM
# .
# Welcome to another exciting ChipWhisperer target build!!
# .
# .
# .
# .
# Compiling:
# Compiling:
# Compiling:
# .
# Compiling:
# -en     project.c ...
# -en     ../../../firmware/mcu/simpleserial/simpleserial.c ...
# -en     ../../../firmware/mcu/hal/hal.c ...
# Compiling:
# -en     ../../../firmware/mcu/hal//stm32f3/stm32f3_hal.c ...
# -en     ../../../firmware/mcu/hal//stm32f3/stm32f3_hal_lowlevel.c ...
# .
# .
# Compiling:
# .
# Assembling: SecBA_m4.S
# arm-none-eabi-gcc -c -mcpu=cortex-m4 -march=armv7e-m -std=gnu11 -I. -x assembler-with-cpp -mthumb -mfloat-abi=soft -fmessage-length=0 -ffunction-sections -DF_CPU=7372800 -Wa,-gstabs,-adhlns=objdir-CWLITEARM/SecBA_m4.lst -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal//stm32f3 -I../../../firmware/mcu/hal//stm32f3/CMSIS -I../../../firmware/mcu/hal//stm32f3/CMSIS/core -I../../../firmware/mcu/hal//stm32f3/CMSIS/device -I../../../firmware/mcu/hal//stm32f4/Legacy -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/crypto/ SecBA_m4.S -o objdir-CWLITEARM/SecBA_m4.o
# -en     ../../../firmware/mcu/hal//stm32f3/stm32f3_sysmem.c ...
# Assembling: SecAB_m4.S
# arm-none-eabi-gcc -c -mcpu=cortex-m4 -march=armv7e-m -std=gnu11 -I. -x assembler-with-cpp -mthumb -mfloat-abi=soft -fmessage-length=0 -ffunction-sections -DF_CPU=7372800 -Wa,-gstabs,-adhlns=objdir-CWLITEARM/SecAB_m4.lst -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal//stm32f3 -I../../../firmware/mcu/hal//stm32f3/CMSIS -I../../../firmware/mcu/hal//stm32f3/CMSIS/core -I../../../firmware/mcu/hal//stm32f3/CMSIS/device -I../../../firmware/mcu/hal//stm32f4/Legacy -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/crypto/ SecAB_m4.S -o objdir-CWLITEARM/SecAB_m4.o
# .
# .
# Assembling: SecINC_m4.S
# arm-none-eabi-gcc -c -mcpu=cortex-m4 -march=armv7e-m -std=gnu11 -I. -x assembler-with-cpp -mthumb -mfloat-abi=soft -fmessage-length=0 -ffunction-sections -DF_CPU=7372800 -Wa,-gstabs,-adhlns=objdir-CWLITEARM/SecINC_m4.lst -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal//stm32f3 -I../../../firmware/mcu/hal//stm32f3/CMSIS -I../../../firmware/mcu/hal//stm32f3/CMSIS/core -I../../../firmware/mcu/hal//stm32f3/CMSIS/device -I../../../firmware/mcu/hal//stm32f4/Legacy -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/crypto/ SecINC_m4.S -o objdir-CWLITEARM/SecINC_m4.o
# Assembling: ../../../firmware/mcu/hal//stm32f3/stm32f3_startup.S
# arm-none-eabi-gcc -c -mcpu=cortex-m4 -march=armv7e-m -std=gnu11 -I. -x assembler-with-cpp -mthumb -mfloat-abi=soft -fmessage-length=0 -ffunction-sections -DF_CPU=7372800 -Wa,-gstabs,-adhlns=objdir-CWLITEARM/stm32f3_startup.lst -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal/ -I../../../firmware/mcu/hal//stm32f3 -I../../../firmware/mcu/hal//stm32f3/CMSIS -I../../../firmware/mcu/hal//stm32f3/CMSIS/core -I../../../firmware/mcu/hal//stm32f3/CMSIS/device -I../../../firmware/mcu/hal//stm32f4/Legacy -I../../../firmware/mcu/simpleserial/ -I../../../firmware/mcu/crypto/ ../../../firmware/mcu/hal//stm32f3/stm32f3_startup.S -o objdir-CWLITEARM/stm32f3_startup.o
# -e Done!
# -e Done!
# -e Done!
# -e Done!
# -e Done!
# -e Done!
# .
# LINKING:
# -en     SecINC-CWLITEARM.elf ...
# Memory region         Used Size  Region Size  %age Used
#              RAM:        1704 B        40 KB      4.16%
#              ROM:       12092 B       256 KB      4.61%
# -e Done!
# .
# .
# Creating load file for Flash: SecINC-CWLITEARM.hex
# arm-none-eabi-objcopy -O ihex -R .eeprom -R .fuse -R .lock -R .signature SecINC-CWLITEARM.elf SecINC-CWLITEARM.hex
# .
# Creating load file for Flash: SecINC-CWLITEARM.bin
# arm-none-eabi-objcopy -O binary -R .eeprom -R .fuse -R .lock -R .signature SecINC-CWLITEARM.elf SecINC-CWLITEARM.bin
# Creating load file for EEPROM: SecINC-CWLITEARM.eep
# arm-none-eabi-objcopy -j .eeprom --set-section-flags=.eeprom="alloc,load" \
# --change-section-lma .eeprom=0 --no-change-warnings -O ihex SecINC-CWLITEARM.elf SecINC-CWLITEARM.eep || exit 0
# .
# .
# Creating Extended Listing: SecINC-CWLITEARM.lss
# arm-none-eabi-objdump -h -S -z SecINC-CWLITEARM.elf > SecINC-CWLITEARM.lss
# Creating Symbol Table: SecINC-CWLITEARM.sym
# arm-none-eabi-nm -n SecINC-CWLITEARM.elf > SecINC-CWLITEARM.sym
# Size after:
#    text	   data	    bss	    dec	    hex	filename
#   12068	     24	   1688	  13780	   35d4	SecINC-CWLITEARM.elf
# +--------------------------------------------------------
# + Default target does full rebuild each time.
# + Specify buildtarget == allquick == to avoid full rebuild
# +--------------------------------------------------------
# +--------------------------------------------------------
# + Built for platform CW-Lite Arm \(STM32F3\) with:
# + CRYPTO_TARGET = NONE
# + CRYPTO_OPTIONS = AES128C
# +--------------------------------------------------------

# %%
cw.program_target(scope, prog, "target/SecINC-{}.hex".format(PLATFORM))
# Out:
# Detected known STMF32: STM32F302xB(C)/303xB(C)
# Extended erase (0x44), this can take ten seconds or more
# Attempting to program 12091 bytes at 0x8000000
# STM32F Programming flash...
# STM32F Reading flash...
# Verified flash OK, 12091 bytes

# %%
from random import randint
from tqdm.notebook import trange
from secrets import randbits
import numpy as np

def get_traces(N):
    traces_1 = []
    traces_2 = []
    x = []
    FIXED = 15
    ONE = 1
    
    for i in trange(N, desc='Capturing traces'):
        scope.arm()

        mask = randbits(32)
        x0 = FIXED ^ mask
        x1 = mask

        x0_0 = x0 % (2**8)
        x0_1 = (x0 % (2**16)) >> 8
        x0_2 = (x0 % (2**24)) >> 16
        x0_3 = x0 >> 24

        x1_0 = x1 % (2**8)
        x1_1 = (x1 % (2**16)) >> 8
        x1_2 = (x1 % (2**24)) >> 16
        x1_3 = x1 >> 24
        
        fixed_text = bytearray([x0_0, x0_1, x0_2, x0_3, x1_0, x1_1, x1_2, x1_3])
        
        mask = randbits(32)
        y0 = ONE ^ mask
        y1 = mask
        
        y0_0 = y0 % (2**8)
        y0_1 = (y0 % (2**16)) >> 8
        y0_2 = (y0 % (2**24)) >> 16
        y0_3 = y0 >> 24

        y1_0 = y1 % (2**8)
        y1_1 = (y1 % (2**16)) >> 8
        y1_2 = (y1 % (2**24)) >> 16
        y1_3 = y1 >> 24
        
        fixed_text.extend([y0_0, y0_1, y0_2, y0_3, y1_0, y1_1, y1_2, y1_3])

        randomness = bytearray([randbits(8) for _ in range(8)])
        fixed_text.extend(randomness)
            
        if randbits(1):
            val = ((x0^x1) + (y0^y1)) % 2**32 

            target.simpleserial_write('p', fixed_text)
             
            ret = scope.capture()
            t = scope.adc.trig_count
            if ret:
                print("Target timed out!")
            response = target.simpleserial_read('r', 4)
            traces_1.append(scope.get_last_trace())
        else:
            text = bytearray([randbits(8) for _ in range(len(fixed_text))])

            rnd_x0 = (text[3] << 24) |(text[2] << 16) | (text[1] << 8) | text[0]
            rnd_x1 = (text[7] << 24) |(text[6] << 16) | (text[5] << 8) | text[4]
            
            text[8] = fixed_text[8]
            text[9] = fixed_text[9]
            text[10] = fixed_text[10]
            text[11] = fixed_text[11]
            text[12] = fixed_text[12]
            text[13] = fixed_text[13]
            text[14] = fixed_text[14]
            text[15] = fixed_text[15]
            
            val = ((rnd_x0 ^ rnd_x1) + (y0^y1)) %2**32 
    
            target.simpleserial_write('p', text)
            ret = scope.capture()
            if ret:
                print("Target timed out!")
            response = target.simpleserial_read('r', 4)
            traces_2.append(scope.get_last_trace())

        if VERBOSE:
            print(val == (int(response[3])<<24) + (int(response[2])<<16) + (int(response[1])<<8) + int(response[0]))
            
    size = min(len(traces_1), len(traces_2))
    
    print("Trigger up for", t, "ADC cycles")
    return (traces_1[:size], traces_2[:size], x)

# %%
ch = 0
if ch == 0:
    VERBOSE = False
    nb_traces = 200000
    traces_1, traces_2, x = get_traces(nb_traces)
else:
    VERBOSE = True
    nb_traces = 100
    traces_1, traces_2, x = get_traces(nb_traces)
# Out:
# Capturing traces:   0%|          | 0/200000 [00:00<?, ?it/s]
# Trigger up for 1864 ADC cycles

# %%
# %matplotlib ipympl
from scipy.stats import ttest_ind
import matplotlib.pyplot as plt
from scipy.stats import norm

alpha = 10**(-5) # error rate
sigma = 1 - (1 - alpha)**(1/samples)
th = norm.ppf(1 - sigma/2) # we adapt the threshold depending on number of samples
t_val = ttest_ind(traces_1, traces_2, axis=0, equal_var=False)[0]
plt.close()
plt.plot(t_val[0:], linewidth=0.75)
plt.plot([th]*scope.adc.samples, color = 'r')
plt.plot([-th]*scope.adc.samples, color='r')
y_offset = 0.5 * th  
plt.text(
    2,                  
    th + y_offset,
    f"th = {th:.2f}",
    color='black',
    fontsize=9,
    verticalalignment='bottom'
)
plt.ylim(-50, 50)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib ipympl
import matplotlib.pyplot as plt

plt.close()
for t in traces_1[:10]:
    plt.plot(t[:], linewidth=0.5)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
target.dis()
scope.dis()
# Out:
# True
